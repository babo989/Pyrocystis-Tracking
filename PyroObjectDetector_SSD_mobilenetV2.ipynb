# %% [markdown]
# <a href="https://colab.research.google.com/github/babo989/Pyrocystis-Tracking/blob/main/PyroObjectDetector_SSD_mobilenetV2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **TFrecord creation using annotated images from labelimg**
# https://github.com/HumanSignal/labelImg

# %%
import os
import glob
import pandas as pd
import xml.etree.ElementTree as ET
import io
import tensorflow as tf
from PIL import Image
from object_detection.utils import dataset_util
from collections import namedtuple

def xml_to_csv(path):
    xml_list = []
    for xml_file in glob.glob(path + '/*.xml'):
        tree = ET.parse(xml_file)
        root = tree.getroot()
        for member in root.findall('object'):
            value = (root.find('filename').text,
                     int(root.find('size')[0].text),
                     int(root.find('size')[1].text),
                     member[0].text,
                     int(member[4][0].text),
                     int(member[4][1].text),
                     int(member[4][2].text),
                     int(member[4][3].text)
                     )
            xml_list.append(value)
    column_name = ['filename', 'width', 'height', 'class', 'xmin', 'ymin', 'xmax', 'ymax']
    xml_df = pd.DataFrame(xml_list, columns=column_name)
    return xml_df

def main():
    # paths to your directory containing the XML files
    xml_path = '/content/drive/MyDrive/Woods_Hole_1_9_4/annotations'
    output_path = '/content/drive/MyDrive/Woods_Hole_1_9_4'
    xml_df = xml_to_csv(xml_path)
    xml_df.to_csv(os.path.join(output_path, 'labels.csv'), index=None)
    print('Successfully converted xml to csv.')

main()

# %%
# Paths
DATA_BASE_PATH = '/content/drive/MyDrive/Woods_Hole_1_9_4/'
IMAGE_PATH = os.path.join(DATA_BASE_PATH, 'images/')
OUTPUT_TRAIN_PATH = os.path.join(DATA_BASE_PATH, 'train.record')
OUTPUT_TEST_PATH = os.path.join(DATA_BASE_PATH, 'test.record')

# Helper functions
def class_text_to_int(row_label):
    if row_label == 'pyro':
        return 1
    else:
        raise ValueError(f"Class {row_label} not found in the mapping.")


def split(df, group):
    data = namedtuple('data', ['filename', 'object'])
    gb = df.groupby(group)
    return [data(filename, gb.get_group(x)) for filename, x in zip(gb.groups.keys(), gb.groups)]

def bytes_list_feature(values):
    return tf.train.Feature(bytes_list=tf.train.BytesList(value=values))

def create_tf_example(group, path):
    with tf.io.gfile.GFile(os.path.join(path, '{}'.format(group.filename)), 'rb') as fid:
        encoded_jpg = fid.read()
    encoded_jpg_io = io.BytesIO(encoded_jpg)
    image = Image.open(encoded_jpg_io)
    width, height = image.size

    filename = group.filename.encode('utf8')
    image_format = b'jpg'
    xmins = []
    xmaxs = []
    ymins = []
    ymaxs = []
    classes_text = []
    classes = []

    for index, row in group.object.iterrows():
        xmins.append(row['xmin'] / width)
        xmaxs.append(row['xmax'] / width)
        ymins.append(row['ymin'] / height)
        ymaxs.append(row['ymax'] / height)
        classes_text.append(row['class'].encode('utf8'))
        classes.append(class_text_to_int(row['class']))

    tf_example = tf.train.Example(features=tf.train.Features(feature={
        'image/height': dataset_util.int64_feature(height),
        'image/width': dataset_util.int64_feature(width),
        'image/filename': dataset_util.bytes_feature(filename),
        'image/source_id': dataset_util.bytes_feature(filename),
        'image/encoded': dataset_util.bytes_feature(encoded_jpg),
        'image/format': dataset_util.bytes_feature(image_format),
        'image/object/bbox/xmin': dataset_util.float_list_feature(xmins),
        'image/object/bbox/xmax': dataset_util.float_list_feature(xmaxs),
        'image/object/bbox/ymin': dataset_util.float_list_feature(ymins),
        'image/object/bbox/ymax': dataset_util.float_list_feature(ymaxs),
        'image/object/class/text': bytes_list_feature(classes_text),
        'image/object/class/label': dataset_util.int64_list_feature(classes),
    }))
    return tf_example

# Main function
def main():
    writer = tf.io.TFRecordWriter(OUTPUT_TRAIN_PATH)
    path = IMAGE_PATH
    examples = pd.read_csv(os.path.join(DATA_BASE_PATH, 'labels.csv'))
    grouped = split(examples, 'filename')
    for group in grouped:
        tf_example = create_tf_example(group, path)
        writer.write(tf_example.SerializeToString())

    writer.close()
    print('Successfully created the TFRecord file:', OUTPUT_TRAIN_PATH)

main()

# %% [markdown]
# **Install dependencies and Tensorflow**

# %% [markdown]
# if you are fine-tuning a detector, pick a suitable model from the tensorflow model zoo https://github.com/tensorflow/models/blob/master/research/object_detection/g3doc/tf2_detection_zoo.md
# You can then store these in your google drive for easy access

# %%
# !pip install tf_slim
# Out:
# Requirement already satisfied: tf_slim in /usr/local/lib/python3.10/dist-packages (1.1.0)
# Requirement already satisfied: absl-py>=0.2.2 in /usr/local/lib/python3.10/dist-packages (from tf_slim) (1.4.0)

# %%
# !pip install lvis
# !pip install tf_slim

# !pip install tensorflow_io
# !pip install cython
# !pip install pycocotools
# !pip install tf-models-official
# Out:
# Collecting lvis
#   Downloading lvis-0.5.3-py3-none-any.whl (14 kB)
# Requirement already satisfied: cycler>=0.10.0 in /usr/local/lib/python3.10/dist-packages (from lvis) (0.11.0)
# Requirement already satisfied: Cython>=0.29.12 in /usr/local/lib/python3.10/dist-packages (from lvis) (0.29.36)
# Requirement already satisfied: kiwisolver>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from lvis) (1.4.4)
# Requirement already satisfied: matplotlib>=3.1.1 in /usr/local/lib/python3.10/dist-packages (from lvis) (3.7.2)
# Requirement already satisfied: numpy>=1.18.2 in /usr/local/lib/python3.10/dist-packages (from lvis) (1.25.2)
# Requirement already satisfied: opencv-python>=4.1.0.25 in /usr/local/lib/python3.10/dist-packages (from lvis) (4.8.0.76)
# Requirement already satisfied: pyparsing>=2.4.0 in /usr/local/lib/python3.10/dist-packages (from lvis) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.8.0 in /usr/local/lib/python3.10/dist-packages (from lvis) (2.8.2)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.10/dist-packages (from lvis) (1.16.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.1.1->lvis) (1.1.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.1.1->lvis) (4.42.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.1.1->lvis) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.1.1->lvis) (10.0.0)
# Installing collected packages: lvis
# Successfully installed lvis-0.5.3
# Requirement already satisfied: tf_slim in /usr/local/lib/python3.10/dist-packages (1.1.0)
# Requirement already satisfied: absl-py>=0.2.2 in /usr/local/lib/python3.10/dist-packages (from tf_slim) (1.4.0)
# Requirement already satisfied: lvis in /usr/local/lib/python3.10/dist-packages (0.5.3)
# Requirement already satisfied: cycler>=0.10.0 in /usr/local/lib/python3.10/dist-packages (from lvis) (0.11.0)
# Requirement already satisfied: Cython>=0.29.12 in /usr/local/lib/python3.10/dist-packages (from lvis) (0.29.36)
# Requirement already satisfied: kiwisolver>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from lvis) (1.4.4)
# Requirement already satisfied: matplotlib>=3.1.1 in /usr/local/lib/python3.10/dist-packages (from lvis) (3.7.2)
# Requirement already satisfied: numpy>=1.18.2 in /usr/local/lib/python3.10/dist-packages (from lvis) (1.25.2)
# Requirement already satisfied: opencv-python>=4.1.0.25 in /usr/local/lib/python3.10/dist-packages (from lvis) (4.8.0.76)
# Requirement already satisfied: pyparsing>=2.4.0 in /usr/local/lib/python3.10/dist-packages (from lvis) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.8.0 in /usr/local/lib/python3.10/dist-packages (from lvis) (2.8.2)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.10/dist-packages (from lvis) (1.16.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.1.1->lvis) (1.1.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.1.1->lvis) (4.42.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.1.1->lvis) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.1.1->lvis) (10.0.0)
# Collecting tensorflow_io
#   Downloading tensorflow_io-0.33.0-cp310-cp310-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (28.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 28.6/28.6 MB 42.8 MB/s eta 0:00:00
# Requirement already satisfied: tensorflow-io-gcs-filesystem==0.33.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow_io) (0.33.0)
# Installing collected packages: tensorflow_io
# Successfully installed tensorflow_io-0.33.0
# Requirement already satisfied: cython in /usr/local/lib/python3.10/dist-packages (0.29.36)
# Requirement already satisfied: pycocotools in /usr/local/lib/python3.10/dist-packages (2.0.6)
# Requirement already satisfied: matplotlib>=2.1.0 in /usr/local/lib/python3.10/dist-packages (from pycocotools) (3.7.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from pycocotools) (1.25.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.1.0->pycocotools) (1.1.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.1.0->pycocotools) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.1.0->pycocotools) (4.42.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.1.0->pycocotools) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.1.0->pycocotools) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.1.0->pycocotools) (10.0.0)
# Requirement already satisfied: pyparsing<3.1,>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.1.0->pycocotools) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.1.0->pycocotools) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib>=2.1.0->pycocotools) (1.16.0)

# %%
# !git clone https://github.com/tensorflow/models.git
# Out:
# Cloning into 'models'...
# remote: Enumerating objects: 87135, done.
# remote: Counting objects: 100% (889/889), done.
# remote: Compressing objects: 100% (409/409), done.
# remote: Total 87135 (delta 530), reused 800 (delta 472), pack-reused 86246
# Receiving objects: 100% (87135/87135), 599.13 MiB | 48.54 MiB/s, done.
# Resolving deltas: 100% (62412/62412), done.

# %%
# %cd models/research
# !protoc object_detection/protos/*.proto --python_out=.
# Out:
# /content/models/research

# %%
import os
os.environ['PYTHONPATH'] += ':/content/models/research/:/content/models/research/slim/'

# %% [markdown]
# **Train model**

# %%
from object_detection.model_main_tf2 import main as main_detector

model_dir = '/content/drive/MyDrive/Woods_Hole_1_9_4'
pipeline_config_path = '/content/drive/MyDrive/Woods_Hole_1_9_4/ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8/pipeline.config'

# !python /content/models/research/object_detection/model_main_tf2.py \
    --pipeline_config_path=$pipeline_config_path \
    --model_dir=$model_dir \
    --alsologtostderr \
    --num_train_steps=10000 \
    --sample_1_of_n_eval_examples=0 \
    --num_eval_steps=0
# Out:
# 2023-08-15 16:22:00.115765: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# INFO:tensorflow:Using MirroredStrategy with devices ('/job:localhost/replica:0/task:0/device:CPU:0',)
# I0815 16:22:02.997944 140400719425536 mirrored_strategy.py:419] Using MirroredStrategy with devices ('/job:localhost/replica:0/task:0/device:CPU:0',)
# INFO:tensorflow:Maybe overwriting train_steps: 10000
# I0815 16:22:03.024913 140400719425536 config_util.py:552] Maybe overwriting train_steps: 10000
# INFO:tensorflow:Maybe overwriting use_bfloat16: False
# I0815 16:22:03.025109 140400719425536 config_util.py:552] Maybe overwriting use_bfloat16: False
# WARNING:tensorflow:From /content/models/research/object_detection/model_lib_v2.py:563: StrategyBase.experimental_distribute_datasets_from_function (from tensorflow.python.distribute.distribute_lib) is deprecated and will be removed in a future version.
# Instructions for updating:
# rename to distribute_datasets_from_function
# W0815 16:22:03.056862 140400719425536 deprecation.py:364] From /content/models/research/object_detection/model_lib_v2.py:563: StrategyBase.experimental_distribute_datasets_from_function (from tensorflow.python.distribute.distribute_lib) is deprecated and will be removed in a future version.
# Instructions for updating:
# rename to distribute_datasets_from_function
# INFO:tensorflow:Reading unweighted datasets: ['/content/drive/MyDrive/Woods_Hole_1_9_4/train.record']
# I0815 16:22:03.068677 140400719425536 dataset_builder.py:162] Reading unweighted datasets: ['/content/drive/MyDrive/Woods_Hole_1_9_4/train.record']
# INFO:tensorflow:Reading record datasets for input file: ['/content/drive/MyDrive/Woods_Hole_1_9_4/train.record']
# I0815 16:22:03.069045 140400719425536 dataset_builder.py:79] Reading record datasets for input file: ['/content/drive/MyDrive/Woods_Hole_1_9_4/train.record']
# INFO:tensorflow:Number of filenames to read: 1
# I0815 16:22:03.069143 140400719425536 dataset_builder.py:80] Number of filenames to read: 1
# WARNING:tensorflow:num_readers has been reduced to 1 to match input file shards.
# W0815 16:22:03.069217 140400719425536 dataset_builder.py:86] num_readers has been reduced to 1 to match input file shards.
# WARNING:tensorflow:From /content/models/research/object_detection/builders/dataset_builder.py:100: parallel_interleave (from tensorflow.python.data.experimental.ops.interleave_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.Dataset.interleave(map_func, cycle_length, block_length, num_parallel_calls=tf.data.AUTOTUNE)` instead. If sloppy execution is desired, use `tf.data.Options.deterministic`.
# W0815 16:22:03.076682 140400719425536 deprecation.py:364] From /content/models/research/object_detection/builders/dataset_builder.py:100: parallel_interleave (from tensorflow.python.data.experimental.ops.interleave_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.Dataset.interleave(map_func, cycle_length, block_length, num_parallel_calls=tf.data.AUTOTUNE)` instead. If sloppy execution is desired, use `tf.data.Options.deterministic`.
# WARNING:tensorflow:From /content/models/research/object_detection/builders/dataset_builder.py:235: DatasetV1.map_with_legacy_function (from tensorflow.python.data.ops.dataset_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.Dataset.map()
# W0815 16:22:03.098263 140400719425536 deprecation.py:364] From /content/models/research/object_detection/builders/dataset_builder.py:235: DatasetV1.map_with_legacy_function (from tensorflow.python.data.ops.dataset_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.Dataset.map()
# WARNING:tensorflow:From /usr/local/lib/python3.10/dist-packages/tensorflow/python/util/dispatch.py:1176: sparse_to_dense (from tensorflow.python.ops.sparse_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Create a `tf.sparse.SparseTensor` and use `tf.sparse.to_dense` instead.
# W0815 16:22:10.647263 140400719425536 deprecation.py:364] From /usr/local/lib/python3.10/dist-packages/tensorflow/python/util/dispatch.py:1176: sparse_to_dense (from tensorflow.python.ops.sparse_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Create a `tf.sparse.SparseTensor` and use `tf.sparse.to_dense` instead.
# WARNING:tensorflow:From /usr/local/lib/python3.10/dist-packages/tensorflow/python/util/dispatch.py:1176: sample_distorted_bounding_box (from tensorflow.python.ops.image_ops_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# `seed2` arg is deprecated.Use sample_distorted_bounding_box_v2 instead.
# W0815 16:22:13.912922 140400719425536 deprecation.py:364] From /usr/local/lib/python3.10/dist-packages/tensorflow/python/util/dispatch.py:1176: sample_distorted_bounding_box (from tensorflow.python.ops.image_ops_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# `seed2` arg is deprecated.Use sample_distorted_bounding_box_v2 instead.
# WARNING:tensorflow:From /usr/local/lib/python3.10/dist-packages/tensorflow/python/util/dispatch.py:1176: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.cast` instead.
# W0815 16:22:15.729407 140400719425536 deprecation.py:364] From /usr/local/lib/python3.10/dist-packages/tensorflow/python/util/dispatch.py:1176: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.cast` instead.
# 2023-08-15 16:22:18.447225: W tensorflow/core/framework/dataset.cc:956] Input of GeneratorDatasetOp::Dataset will not be optimized because the dataset does not implement the AsGraphDefInternal() method needed to apply optimizations.
# /usr/local/lib/python3.10/dist-packages/keras/src/backend.py:452: UserWarning: `tf.keras.backend.set_learning_phase` is deprecated and will be removed after 2020-10-11. To update it, simply pass a True/False value to the `training` argument of the `__call__` method of your layer or model.
#   warnings.warn(
# I0815 16:22:35.858762 140383849784896 api.py:460] feature_map_spatial_dims: [(40, 40), (20, 20), (10, 10), (5, 5), (3, 3)]
# I0815 16:22:44.685134 140383849784896 api.py:460] feature_map_spatial_dims: [(40, 40), (20, 20), (10, 10), (5, 5), (3, 3)]
# 2023-08-15 16:22:50.403301: W tensorflow/core/framework/dataset.cc:956] Input of GeneratorDatasetOp::Dataset will not be optimized because the dataset does not implement the AsGraphDefInternal() method needed to apply optimizations.
# WARNING:tensorflow:From /usr/local/lib/python3.10/dist-packages/tensorflow/python/util/deprecation.py:648: calling map_fn_v2 (from tensorflow.python.ops.map_fn) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Use fn_output_signature instead
# W0815 16:22:51.872998 140383891748416 deprecation.py:569] From /usr/local/lib/python3.10/dist-packages/tensorflow/python/util/deprecation.py:648: calling map_fn_v2 (from tensorflow.python.ops.map_fn) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Use fn_output_signature instead
# I0815 16:22:53.125053 140383891748416 api.py:460] feature_map_spatial_dims: [(40, 40), (20, 20), (10, 10), (5, 5), (3, 3)]
# I0815 16:22:59.559797 140383891748416 api.py:460] feature_map_spatial_dims: [(40, 40), (20, 20), (10, 10), (5, 5), (3, 3)]
# I0815 16:23:05.622116 140383891748416 api.py:460] feature_map_spatial_dims: [(40, 40), (20, 20), (10, 10), (5, 5), (3, 3)]
# I0815 16:23:11.826711 140383891748416 api.py:460] feature_map_spatial_dims: [(40, 40), (20, 20), (10, 10), (5, 5), (3, 3)]
# INFO:tensorflow:Step 100 per-step time 1.081s
# I0815 16:24:39.542633 140400719425536 model_lib_v2.py:705] Step 100 per-step time 1.081s
# INFO:tensorflow:{'Loss/classification_loss': 0.10943217,
#  'Loss/localization_loss': 0.08626289,
#  'Loss/regularization_loss': 0.15346028,
#  'Loss/total_loss': 0.34915534,
#  'learning_rate': 0.0319994}
# I0815 16:24:39.543047 140400719425536 model_lib_v2.py:708] {'Loss/classification_loss': 0.10943217,
#  'Loss/localization_loss': 0.08626289,
#  'Loss/regularization_loss': 0.15346028,
#  'Loss/total_loss': 0.34915534,
#  'learning_rate': 0.0319994}
# INFO:tensorflow:Step 200 per-step time 0.580s
# I0815 16:25:37.500720 140400719425536 model_lib_v2.py:705] Step 200 per-step time 0.580s
# INFO:tensorflow:{'Loss/classification_loss': 0.10080119,
#  'Loss/localization_loss': 0.06685912,
#  'Loss/regularization_loss': 0.1532559,
#  'Loss/total_loss': 0.3209162,
#  'learning_rate': 0.0373328}
# I0815 16:25:37.501090 140400719425536 model_lib_v2.py:708] {'Loss/classification_loss': 0.10080119,
#  'Loss/localization_loss': 0.06685912,
#  'Loss/regularization_loss': 0.1532559,
#  'Loss/total_loss': 0.3209162,
#  'learning_rate': 0.0373328}
# INFO:tensorflow:Step 300 per-step time 0.557s
# I0815 16:26:33.215401 140400719425536 model_lib_v2.py:705] Step 300 per-step time 0.557s
# INFO:tensorflow:{'Loss/classification_loss': 0.120365284,
#  'Loss/localization_loss': 0.18904828,
#  'Loss/regularization_loss': 0.1529857,
#  'Loss/total_loss': 0.46239924,
#  'learning_rate': 0.0426662}
# I0815 16:26:33.215737 140400719425536 model_lib_v2.py:708] {'Loss/classification_loss': 0.120365284,
#  'Loss/localization_loss': 0.18904828,
#  'Loss/regularization_loss': 0.1529857,
#  'Loss/total_loss': 0.46239924,
#  'learning_rate': 0.0426662}
# INFO:tensorflow:Step 400 per-step time 0.543s
# I0815 16:27:27.474130 140400719425536 model_lib_v2.py:705] Step 400 per-step time 0.543s
# INFO:tensorflow:{'Loss/classification_loss': 0.13671352,
#  'Loss/localization_loss': 0.047127135,
#  'Loss/regularization_loss': 0.15272824,
#  'Loss/total_loss': 0.3365689,
#  'learning_rate': 0.047999598}
# I0815 16:27:27.474530 140400719425536 model_lib_v2.py:708] {'Loss/classification_loss': 0.13671352,
#  'Loss/localization_loss': 0.047127135,
#  'Loss/regularization_loss': 0.15272824,
#  'Loss/total_loss': 0.3365689,
#  'learning_rate': 0.047999598}
# INFO:tensorflow:Step 500 per-step time 0.564s
# I0815 16:28:23.896909 140400719425536 model_lib_v2.py:705] Step 500 per-step time 0.564s
# INFO:tensorflow:{'Loss/classification_loss': 0.089333944,
#  'Loss/localization_loss': 0.04703404,
#  'Loss/regularization_loss': 0.1524059,
#  'Loss/total_loss': 0.2887739,
#  'learning_rate': 0.053333}
# I0815 16:28:23.897312 140400719425536 model_lib_v2.py:708] {'Loss/classification_loss': 0.089333944,
#  'Loss/localization_loss': 0.04703404,
#  'Loss/regularization_loss': 0.1524059,
#  'Loss/total_loss': 0.2887739,
#  'learning_rate': 0.053333}
# INFO:tensorflow:Step 600 per-step time 0.553s
# I0815 16:29:19.161725 140400719425536 model_lib_v2.py:705] Step 600 per-step time 0.553s
# INFO:tensorflow:{'Loss/classification_loss': 0.18360732,
#  'Loss/localization_loss': 0.080716886,
#  'Loss/regularization_loss': 0.15203033,
#  'Loss/total_loss': 0.41635454,
#  'learning_rate': 0.0586664}
# I0815 16:29:19.162111 140400719425536 model_lib_v2.py:708] {'Loss/classification_loss': 0.18360732,
#  'Loss/localization_loss': 0.080716886,
#  'Loss/regularization_loss': 0.15203033,
#  'Loss/total_loss': 0.41635454,
#  'learning_rate': 0.0586664}
# INFO:tensorflow:Step 700 per-step time 0.541s
# I0815 16:30:13.298014 140400719425536 model_lib_v2.py:705] Step 700 per-step time 0.541s
# INFO:tensorflow:{'Loss/classification_loss': 0.055814017,
#  'Loss/localization_loss': 0.023993159,
#  'Loss/regularization_loss': 0.15160754,
#  'Loss/total_loss': 0.23141472,
#  'learning_rate': 0.0639998}
# I0815 16:30:13.298386 140400719425536 model_lib_v2.py:708] {'Loss/classification_loss': 0.055814017,
#  'Loss/localization_loss': 0.023993159,
#  'Loss/regularization_loss': 0.15160754,
#  'Loss/total_loss': 0.23141472,
#  'learning_rate': 0.0639998}
# INFO:tensorflow:Step 800 per-step time 0.542s
# I0815 16:31:07.474175 140400719425536 model_lib_v2.py:705] Step 800 per-step time 0.542s
# INFO:tensorflow:{'Loss/classification_loss': 0.109645076,
#  'Loss/localization_loss': 0.030554429,
#  'Loss/regularization_loss': 0.15107752,
#  'Loss/total_loss': 0.29127705,
#  'learning_rate': 0.069333196}
# I0815 16:31:07.474546 140400719425536 model_lib_v2.py:708] {'Loss/classification_loss': 0.109645076,
#  'Loss/localization_loss': 0.030554429,
#  'Loss/regularization_loss': 0.15107752,
#  'Loss/total_loss': 0.29127705,
#  'learning_rate': 0.069333196}
# INFO:tensorflow:Step 900 per-step time 0.560s
# I0815 16:32:03.482645 140400719425536 model_lib_v2.py:705] Step 900 per-step time 0.560s
# INFO:tensorflow:{'Loss/classification_loss': 0.1156387,
#  'Loss/localization_loss': 0.076424055,
#  'Loss/regularization_loss': 0.15058912,
#  'Loss/total_loss': 0.3426519,
#  'learning_rate': 0.074666604}
# I0815 16:32:03.483012 140400719425536 model_lib_v2.py:708] {'Loss/classification_loss': 0.1156387,
#  'Loss/localization_loss': 0.076424055,
#  'Loss/regularization_loss': 0.15058912,
#  'Loss/total_loss': 0.3426519,
#  'learning_rate': 0.074666604}
# INFO:tensorflow:Step 1000 per-step time 0.562s
# I0815 16:32:59.643911 140400719425536 model_lib_v2.py:705] Step 1000 per-step time 0.562s
# INFO:tensorflow:{'Loss/classification_loss': 0.11656615,
#  'Loss/localization_loss': 0.034097582,
#  'Loss/regularization_loss': 0.15014075,
#  'Loss/total_loss': 0.30080447,
#  'learning_rate': 0.08}
# I0815 16:32:59.644290 140400719425536 model_lib_v2.py:708] {'Loss/classification_loss': 0.11656615,
#  'Loss/localization_loss': 0.034097582,
#  'Loss/regularization_loss': 0.15014075,
#  'Loss/total_loss': 0.30080447,
#  'learning_rate': 0.08}
# INFO:tensorflow:Step 1100 per-step time 0.551s
# I0815 16:33:54.730211 140400719425536 model_lib_v2.py:705] Step 1100 per-step time 0.551s
# INFO:tensorflow:{'Loss/classification_loss': 0.105725825,
#  'Loss/localization_loss': 0.037339695,
#  'Loss/regularization_loss': 0.14944173,
#  'Loss/total_loss': 0.29250723,
#  'learning_rate': 0.07999918}
# I0815 16:33:54.730710 140400719425536 model_lib_v2.py:708] {'Loss/classification_loss': 0.105725825,
#  'Loss/localization_loss': 0.037339695,
#  'Loss/regularization_loss': 0.14944173,
#  'Loss/total_loss': 0.29250723,
#  'learning_rate': 0.07999918}
# INFO:tensorflow:Step 1200 per-step time 0.545s
# I0815 16:34:49.212411 140400719425536 model_lib_v2.py:705] Step 1200 per-step time 0.545s
# INFO:tensorflow:{'Loss/classification_loss': 0.07401115,
#  'Loss/localization_loss': 0.03760005,
#  'Loss/regularization_loss': 0.14876513,
#  'Loss/total_loss': 0.26037633,
#  'learning_rate': 0.079996705}
# I0815 16:34:49.212779 140400719425536 model_lib_v2.py:708] {'Loss/classification_loss': 0.07401115,
#  'Loss/localization_loss': 0.03760005,
#  'Loss/regularization_loss': 0.14876513,
#  'Loss/total_loss': 0.26037633,
#  'learning_rate': 0.079996705}
# INFO:tensorflow:Step 1300 per-step time 0.563s
# I0815 16:35:45.476523 140400719425536 model_lib_v2.py:705] Step 1300 per-step time 0.563s
# INFO:tensorflow:{'Loss/classification_loss': 0.085732006,
#  'Loss/localization_loss': 0.045486774,
#  'Loss/regularization_loss': 0.1480769,
#  'Loss/total_loss': 0.27929568,
#  'learning_rate': 0.0799926}
# I0815 16:35:45.477056 140400719425536 model_lib_v2.py:708] {'Loss/classification_loss': 0.085732006,
#  'Loss/localization_loss': 0.045486774,
#  'Loss/regularization_loss': 0.1480769,
#  'Loss/total_loss': 0.27929568,
#  'learning_rate': 0.0799926}
# INFO:tensorflow:Step 1400 per-step time 0.570s
# I0815 16:36:42.487839 140400719425536 model_lib_v2.py:705] Step 1400 per-step time 0.570s
# INFO:tensorflow:{'Loss/classification_loss': 0.08349058,
#  'Loss/localization_loss': 0.025831008,
#  'Loss/regularization_loss': 0.14800371,
#  'Loss/total_loss': 0.2573253,
#  'learning_rate': 0.07998685}
# I0815 16:36:42.488306 140400719425536 model_lib_v2.py:708] {'Loss/classification_loss': 0.08349058,
#  'Loss/localization_loss': 0.025831008,
#  'Loss/regularization_loss': 0.14800371,
#  'Loss/total_loss': 0.2573253,
#  'learning_rate': 0.07998685}
# INFO:tensorflow:Step 1500 per-step time 0.548s
# I0815 16:37:37.317700 140400719425536 model_lib_v2.py:705] Step 1500 per-step time 0.548s
# INFO:tensorflow:{'Loss/classification_loss': 0.091513366,
#  'Loss/localization_loss': 0.10887122,
#  'Loss/regularization_loss': 0.14726645,
#  'Loss/total_loss': 0.34765103,
#  'learning_rate': 0.07997945}
# I0815 16:37:37.318081 140400719425536 model_lib_v2.py:708] {'Loss/classification_loss': 0.091513366,
#  'Loss/localization_loss': 0.10887122,
#  'Loss/regularization_loss': 0.14726645,
#  'Loss/total_loss': 0.34765103,
#  'learning_rate': 0.07997945}
# INFO:tensorflow:Step 1600 per-step time 0.548s
# I0815 16:38:32.097496 140400719425536 model_lib_v2.py:705] Step 1600 per-step time 0.548s
# INFO:tensorflow:{'Loss/classification_loss': 0.10749221,
#  'Loss/localization_loss': 0.07805385,
#  'Loss/regularization_loss': 0.14662322,
#  'Loss/total_loss': 0.3321693,
#  'learning_rate': 0.079970405}
# I0815 16:38:32.098046 140400719425536 model_lib_v2.py:708] {'Loss/classification_loss': 0.10749221,
#  'Loss/localization_loss': 0.07805385,
#  'Loss/regularization_loss': 0.14662322,
#  'Loss/total_loss': 0.3321693,
#  'learning_rate': 0.079970405}
# INFO:tensorflow:Step 1700 per-step time 0.628s
# I0815 16:39:34.925893 140400719425536 model_lib_v2.py:705] Step 1700 per-step time 0.628s
# INFO:tensorflow:{'Loss/classification_loss': 0.077618495,
#  'Loss/localization_loss': 0.025202688,
#  'Loss/regularization_loss': 0.14589761,
#  'Loss/total_loss': 0.2487188,
#  'learning_rate': 0.07995972}
# I0815 16:39:34.926289 140400719425536 model_lib_v2.py:708] {'Loss/classification_loss': 0.077618495,
#  'Loss/localization_loss': 0.025202688,
#  'Loss/regularization_loss': 0.14589761,
#  'Loss/total_loss': 0.2487188,
#  'learning_rate': 0.07995972}
# INFO:tensorflow:Step 1800 per-step time 0.599s
# I0815 16:40:34.796392 140400719425536 model_lib_v2.py:705] Step 1800 per-step time 0.599s
# INFO:tensorflow:{'Loss/classification_loss': 0.052371606,
#  'Loss/localization_loss': 0.029591965,
#  'Loss/regularization_loss': 0.14514916,
#  'Loss/total_loss': 0.22711273,
#  'learning_rate': 0.0799474}
# I0815 16:40:34.796718 140400719425536 model_lib_v2.py:708] {'Loss/classification_loss': 0.052371606,
#  'Loss/localization_loss': 0.029591965,
#  'Loss/regularization_loss': 0.14514916,
#  'Loss/total_loss': 0.22711273,
#  'learning_rate': 0.0799474}
# INFO:tensorflow:Step 1900 per-step time 0.538s
# I0815 16:41:28.608208 140400719425536 model_lib_v2.py:705] Step 1900 per-step time 0.538s
# INFO:tensorflow:{'Loss/classification_loss': 0.061236847,
#  'Loss/localization_loss': 0.018987656,
#  'Loss/regularization_loss': 0.14441945,
#  'Loss/total_loss': 0.22464395,
#  'learning_rate': 0.07993342}
# I0815 16:41:28.608572 140400719425536 model_lib_v2.py:708] {'Loss/classification_loss': 0.061236847,
#  'Loss/localization_loss': 0.018987656,
#  'Loss/regularization_loss': 0.14441945,
#  'Loss/total_loss': 0.22464395,
#  'learning_rate': 0.07993342}
# INFO:tensorflow:Step 2000 per-step time 0.538s
# I0815 16:42:22.407693 140400719425536 model_lib_v2.py:705] Step 2000 per-step time 0.538s
# INFO:tensorflow:{'Loss/classification_loss': 0.04878378,
#  'Loss/localization_loss': 0.024119336,
#  'Loss/regularization_loss': 0.14373475,
#  'Loss/total_loss': 0.21663786,
#  'learning_rate': 0.07991781}
# I0815 16:42:22.408314 140400719425536 model_lib_v2.py:708] {'Loss/classification_loss': 0.04878378,
#  'Loss/localization_loss': 0.024119336,
#  'Loss/regularization_loss': 0.14373475,
#  'Loss/total_loss': 0.21663786,
#  'learning_rate': 0.07991781}
# INFO:tensorflow:Step 2100 per-step time 0.545s
# I0815 16:43:16.941513 140400719425536 model_lib_v2.py:705] Step 2100 per-step time 0.545s
# INFO:tensorflow:{'Loss/classification_loss': 0.082726054,
#  'Loss/localization_loss': 0.01743495,
#  'Loss/regularization_loss': 0.14314426,
#  'Loss/total_loss': 0.24330527,
#  'learning_rate': 0.07990056}
# I0815 16:43:16.941904 140400719425536 model_lib_v2.py:708] {'Loss/classification_loss': 0.082726054,
#  'Loss/localization_loss': 0.01743495,
#  'Loss/regularization_loss': 0.14314426,
#  'Loss/total_loss': 0.24330527,
#  'learning_rate': 0.07990056}
# INFO:tensorflow:Step 2200 per-step time 0.577s
# I0815 16:44:14.599183 140400719425536 model_lib_v2.py:705] Step 2200 per-step time 0.577s
# INFO:tensorflow:{'Loss/classification_loss': 0.069855936,
#  'Loss/localization_loss': 0.017772315,
#  'Loss/regularization_loss': 0.14238149,
#  'Loss/total_loss': 0.23000973,
#  'learning_rate': 0.07988167}
# I0815 16:44:14.599601 140400719425536 model_lib_v2.py:708] {'Loss/classification_loss': 0.069855936,
#  'Loss/localization_loss': 0.017772315,
#  'Loss/regularization_loss': 0.14238149,
#  'Loss/total_loss': 0.23000973,
#  'learning_rate': 0.07988167}
# INFO:tensorflow:Step 2300 per-step time 0.535s
# I0815 16:45:08.079062 140400719425536 model_lib_v2.py:705] Step 2300 per-step time 0.535s
# INFO:tensorflow:{'Loss/classification_loss': 0.055731025,
#  'Loss/localization_loss': 0.024733528,
#  'Loss/regularization_loss': 0.14160593,
#  'Loss/total_loss': 0.22207049,
#  'learning_rate': 0.07986114}
# I0815 16:45:08.079468 140400719425536 model_lib_v2.py:708] {'Loss/classification_loss': 0.055731025,
#  'Loss/localization_loss': 0.024733528,
#  'Loss/regularization_loss': 0.14160593,
#  'Loss/total_loss': 0.22207049,
#  'learning_rate': 0.07986114}
# INFO:tensorflow:Step 2400 per-step time 0.535s
# I0815 16:46:01.584017 140400719425536 model_lib_v2.py:705] Step 2400 per-step time 0.535s
# INFO:tensorflow:{'Loss/classification_loss': 0.052526943,
#  'Loss/localization_loss': 0.023793353,
#  'Loss/regularization_loss': 0.14082727,
#  'Loss/total_loss': 0.21714757,
#  'learning_rate': 0.07983897}
# I0815 16:46:01.584506 140400719425536 model_lib_v2.py:708] {'Loss/classification_loss': 0.052526943,
#  'Loss/localization_loss': 0.023793353,
#  'Loss/regularization_loss': 0.14082727,
#  'Loss/total_loss': 0.21714757,
#  'learning_rate': 0.07983897}
# INFO:tensorflow:Step 2500 per-step time 0.541s
# I0815 16:46:55.665086 140400719425536 model_lib_v2.py:705] Step 2500 per-step time 0.541s
# INFO:tensorflow:{'Loss/classification_loss': 0.06438511,
#  'Loss/localization_loss': 0.02527063,
#  'Loss/regularization_loss': 0.14021172,
#  'Loss/total_loss': 0.22986744,
#  'learning_rate': 0.079815164}
# I0815 16:46:55.665448 140400719425536 model_lib_v2.py:708] {'Loss/classification_loss': 0.06438511,
#  'Loss/localization_loss': 0.02527063,
#  'Loss/regularization_loss': 0.14021172,
#  'Loss/total_loss': 0.22986744,
#  'learning_rate': 0.079815164}
# INFO:tensorflow:Step 2600 per-step time 0.553s
# I0815 16:47:50.987574 140400719425536 model_lib_v2.py:705] Step 2600 per-step time 0.553s
# INFO:tensorflow:{'Loss/classification_loss': 0.03437638,
#  'Loss/localization_loss': 0.017747968,
#  'Loss/regularization_loss': 0.13946292,
#  'Loss/total_loss': 0.19158727,
#  'learning_rate': 0.07978972}
# I0815 16:47:50.987952 140400719425536 model_lib_v2.py:708] {'Loss/classification_loss': 0.03437638,
#  'Loss/localization_loss': 0.017747968,
#  'Loss/regularization_loss': 0.13946292,
#  'Loss/total_loss': 0.19158727,
#  'learning_rate': 0.07978972}
# INFO:tensorflow:Step 2700 per-step time 0.532s
# I0815 16:48:44.171149 140400719425536 model_lib_v2.py:705] Step 2700 per-step time 0.532s
# INFO:tensorflow:{'Loss/classification_loss': 0.07409867,
#  'Loss/localization_loss': 0.012039638,
#  'Loss/regularization_loss': 0.13884652,
#  'Loss/total_loss': 0.22498482,
#  'learning_rate': 0.07976264}
# I0815 16:48:44.171513 140400719425536 model_lib_v2.py:708] {'Loss/classification_loss': 0.07409867,
#  'Loss/localization_loss': 0.012039638,
#  'Loss/regularization_loss': 0.13884652,
#  'Loss/total_loss': 0.22498482,
#  'learning_rate': 0.07976264}
# INFO:tensorflow:Step 2800 per-step time 0.516s
# I0815 16:49:35.759542 140400719425536 model_lib_v2.py:705] Step 2800 per-step time 0.516s
# INFO:tensorflow:{'Loss/classification_loss': 0.08547319,
#  'Loss/localization_loss': 0.025462015,
#  'Loss/regularization_loss': 0.1381089,
#  'Loss/total_loss': 0.2490441,
#  'learning_rate': 0.07973392}
# I0815 16:49:35.759911 140400719425536 model_lib_v2.py:708] {'Loss/classification_loss': 0.08547319,
#  'Loss/localization_loss': 0.025462015,
#  'Loss/regularization_loss': 0.1381089,
#  'Loss/total_loss': 0.2490441,
#  'learning_rate': 0.07973392}
# INFO:tensorflow:Step 2900 per-step time 0.557s
# I0815 16:50:31.438481 140400719425536 model_lib_v2.py:705] Step 2900 per-step time 0.557s
# INFO:tensorflow:{'Loss/classification_loss': 0.053746592,
#  'Loss/localization_loss': 0.018864319,
#  'Loss/regularization_loss': 0.13741231,
#  'Loss/total_loss': 0.21002322,
#  'learning_rate': 0.07970358}
# I0815 16:50:31.439046 140400719425536 model_lib_v2.py:708] {'Loss/classification_loss': 0.053746592,
#  'Loss/localization_loss': 0.018864319,
#  'Loss/regularization_loss': 0.13741231,
#  'Loss/total_loss': 0.21002322,
#  'learning_rate': 0.07970358}
# INFO:tensorflow:Step 3000 per-step time 0.552s
# I0815 16:51:26.674247 140400719425536 model_lib_v2.py:705] Step 3000 per-step time 0.552s
# INFO:tensorflow:{'Loss/classification_loss': 0.07434251,
#  'Loss/localization_loss': 0.016890218,
#  'Loss/regularization_loss': 0.1367998,
#  'Loss/total_loss': 0.22803251,
#  'learning_rate': 0.0796716}
# I0815 16:51:26.674731 140400719425536 model_lib_v2.py:708] {'Loss/classification_loss': 0.07434251,
#  'Loss/localization_loss': 0.016890218,
#  'Loss/regularization_loss': 0.1367998,
#  'Loss/total_loss': 0.22803251,
#  'learning_rate': 0.0796716}
# INFO:tensorflow:Step 3100 per-step time 0.534s
# I0815 16:52:20.034809 140400719425536 model_lib_v2.py:705] Step 3100 per-step time 0.534s
# INFO:tensorflow:{'Loss/classification_loss': 0.057106737,
#  'Loss/localization_loss': 0.018098634,
#  'Loss/regularization_loss': 0.13614094,
#  'Loss/total_loss': 0.21134631,
#  'learning_rate': 0.07963799}
# I0815 16:52:20.035169 140400719425536 model_lib_v2.py:708] {'Loss/classification_loss': 0.057106737,
#  'Loss/localization_loss': 0.018098634,
#  'Loss/regularization_loss': 0.13614094,
#  'Loss/total_loss': 0.21134631,
#  'learning_rate': 0.07963799}
# INFO:tensorflow:Step 3200 per-step time 0.526s
# I0815 16:53:12.671355 140400719425536 model_lib_v2.py:705] Step 3200 per-step time 0.526s
# INFO:tensorflow:{'Loss/classification_loss': 0.059309132,
#  'Loss/localization_loss': 0.016060703,
#  'Loss/regularization_loss': 0.13547842,
#  'Loss/total_loss': 0.21084827,
#  'learning_rate': 0.07960275}
# I0815 16:53:12.671716 140400719425536 model_lib_v2.py:708] {'Loss/classification_loss': 0.059309132,
#  'Loss/localization_loss': 0.016060703,
#  'Loss/regularization_loss': 0.13547842,
#  'Loss/total_loss': 0.21084827,
#  'learning_rate': 0.07960275}
# INFO:tensorflow:Step 3300 per-step time 0.543s
# I0815 16:54:06.980564 140400719425536 model_lib_v2.py:705] Step 3300 per-step time 0.543s
# INFO:tensorflow:{'Loss/classification_loss': 0.09252343,
#  'Loss/localization_loss': 0.028357767,
#  'Loss/regularization_loss': 0.13473116,
#  'Loss/total_loss': 0.25561237,
#  'learning_rate': 0.07956588}
# I0815 16:54:06.980895 140400719425536 model_lib_v2.py:708] {'Loss/classification_loss': 0.09252343,
#  'Loss/localization_loss': 0.028357767,
#  'Loss/regularization_loss': 0.13473116,
#  'Loss/total_loss': 0.25561237,
#  'learning_rate': 0.07956588}
# INFO:tensorflow:Step 3400 per-step time 0.554s
# I0815 16:55:02.394189 140400719425536 model_lib_v2.py:705] Step 3400 per-step time 0.554s
# INFO:tensorflow:{'Loss/classification_loss': 0.12031057,
#  'Loss/localization_loss': 0.04620567,
#  'Loss/regularization_loss': 0.13399825,
#  'Loss/total_loss': 0.3005145,
#  'learning_rate': 0.079527386}
# I0815 16:55:02.394558 140400719425536 model_lib_v2.py:708] {'Loss/classification_loss': 0.12031057,
#  'Loss/localization_loss': 0.04620567,
#  'Loss/regularization_loss': 0.13399825,
#  'Loss/total_loss': 0.3005145,
#  'learning_rate': 0.079527386}
# INFO:tensorflow:Step 3500 per-step time 0.530s
# I0815 16:55:55.396714 140400719425536 model_lib_v2.py:705] Step 3500 per-step time 0.530s
# INFO:tensorflow:{'Loss/classification_loss': 0.053771015,
#  'Loss/localization_loss': 0.014767781,
#  'Loss/regularization_loss': 0.13325928,
#  'Loss/total_loss': 0.20179808,
#  'learning_rate': 0.07948727}
# I0815 16:55:55.397077 140400719425536 model_lib_v2.py:708] {'Loss/classification_loss': 0.053771015,
#  'Loss/localization_loss': 0.014767781,
#  'Loss/regularization_loss': 0.13325928,
#  'Loss/total_loss': 0.20179808,
#  'learning_rate': 0.07948727}
# INFO:tensorflow:Step 3600 per-step time 0.545s
# I0815 16:56:49.939292 140400719425536 model_lib_v2.py:705] Step 3600 per-step time 0.545s
# INFO:tensorflow:{'Loss/classification_loss': 0.036932655,
#  'Loss/localization_loss': 0.024665931,
#  'Loss/regularization_loss': 0.1325417,
#  'Loss/total_loss': 0.19414029,
#  'learning_rate': 0.079445526}
# I0815 16:56:49.939627 140400719425536 model_lib_v2.py:708] {'Loss/classification_loss': 0.036932655,
#  'Loss/localization_loss': 0.024665931,
#  'Loss/regularization_loss': 0.1325417,
#  'Loss/total_loss': 0.19414029,
#  'learning_rate': 0.079445526}
# INFO:tensorflow:Step 3700 per-step time 0.523s
# I0815 16:57:42.265489 140400719425536 model_lib_v2.py:705] Step 3700 per-step time 0.523s
# INFO:tensorflow:{'Loss/classification_loss': 0.05255484,
#  'Loss/localization_loss': 0.009360091,
#  'Loss/regularization_loss': 0.13183194,
#  'Loss/total_loss': 0.19374688,
#  'learning_rate': 0.07940216}
# I0815 16:57:42.265892 140400719425536 model_lib_v2.py:708] {'Loss/classification_loss': 0.05255484,
#  'Loss/localization_loss': 0.009360091,
#  'Loss/regularization_loss': 0.13183194,
#  'Loss/total_loss': 0.19374688,
#  'learning_rate': 0.07940216}
# INFO:tensorflow:Step 3800 per-step time 0.534s
# I0815 16:58:35.693214 140400719425536 model_lib_v2.py:705] Step 3800 per-step time 0.534s
# INFO:tensorflow:{'Loss/classification_loss': 0.03630643,
#  'Loss/localization_loss': 0.021229897,
#  'Loss/regularization_loss': 0.131151,
#  'Loss/total_loss': 0.18868732,
#  'learning_rate': 0.079357184}
# I0815 16:58:35.693548 140400719425536 model_lib_v2.py:708] {'Loss/classification_loss': 0.03630643,
#  'Loss/localization_loss': 0.021229897,
#  'Loss/regularization_loss': 0.131151,
#  'Loss/total_loss': 0.18868732,
#  'learning_rate': 0.079357184}
# INFO:tensorflow:Step 3900 per-step time 0.543s
# I0815 16:59:29.967291 140400719425536 model_lib_v2.py:705] Step 3900 per-step time 0.543s
# INFO:tensorflow:{'Loss/classification_loss': 0.039929107,
#  'Loss/localization_loss': 0.010666222,
#  'Loss/regularization_loss': 0.13048668,
#  'Loss/total_loss': 0.18108201,
#  'learning_rate': 0.07931058}
# I0815 16:59:29.967674 140400719425536 model_lib_v2.py:708] {'Loss/classification_loss': 0.039929107,
#  'Loss/localization_loss': 0.010666222,
#  'Loss/regularization_loss': 0.13048668,
#  'Loss/total_loss': 0.18108201,
#  'learning_rate': 0.07931058}
# INFO:tensorflow:Step 4000 per-step time 0.539s
# I0815 17:00:23.908516 140400719425536 model_lib_v2.py:705] Step 4000 per-step time 0.539s
# INFO:tensorflow:{'Loss/classification_loss': 0.051581014,
#  'Loss/localization_loss': 0.035172343,
#  'Loss/regularization_loss': 0.1297759,
#  'Loss/total_loss': 0.21652925,
#  'learning_rate': 0.07926236}
# I0815 17:00:23.908851 140400719425536 model_lib_v2.py:708] {'Loss/classification_loss': 0.051581014,
#  'Loss/localization_loss': 0.035172343,
#  'Loss/regularization_loss': 0.1297759,
#  'Loss/total_loss': 0.21652925,
#  'learning_rate': 0.07926236}
# INFO:tensorflow:Step 4100 per-step time 0.586s
# I0815 17:01:22.497016 140400719425536 model_lib_v2.py:705] Step 4100 per-step time 0.586s
# INFO:tensorflow:{'Loss/classification_loss': 0.040037308,
#  'Loss/localization_loss': 0.023038974,
#  'Loss/regularization_loss': 0.12909159,
#  'Loss/total_loss': 0.19216786,
#  'learning_rate': 0.07921253}
# I0815 17:01:22.497443 140400719425536 model_lib_v2.py:708] {'Loss/classification_loss': 0.040037308,
#  'Loss/localization_loss': 0.023038974,
#  'Loss/regularization_loss': 0.12909159,
#  'Loss/total_loss': 0.19216786,
#  'learning_rate': 0.07921253}
# INFO:tensorflow:Step 4200 per-step time 0.596s
# I0815 17:02:22.089091 140400719425536 model_lib_v2.py:705] Step 4200 per-step time 0.596s
# INFO:tensorflow:{'Loss/classification_loss': 0.050779533,
#  'Loss/localization_loss': 0.02080635,
#  'Loss/regularization_loss': 0.12859987,
#  'Loss/total_loss': 0.20018575,
#  'learning_rate': 0.07916109}
# I0815 17:02:22.089576 140400719425536 model_lib_v2.py:708] {'Loss/classification_loss': 0.050779533,
#  'Loss/localization_loss': 0.02080635,
#  'Loss/regularization_loss': 0.12859987,
#  'Loss/total_loss': 0.20018575,
#  'learning_rate': 0.07916109}
# INFO:tensorflow:Step 4300 per-step time 0.557s
# I0815 17:03:17.796838 140400719425536 model_lib_v2.py:705] Step 4300 per-step time 0.557s
# INFO:tensorflow:{'Loss/classification_loss': 0.04588547,
#  'Loss/localization_loss': 0.011916648,
#  'Loss/regularization_loss': 0.12794073,
#  'Loss/total_loss': 0.18574286,
#  'learning_rate': 0.07910804}
# I0815 17:03:17.797177 140400719425536 model_lib_v2.py:708] {'Loss/classification_loss': 0.04588547,
#  'Loss/localization_loss': 0.011916648,
#  'Loss/regularization_loss': 0.12794073,
#  'Loss/total_loss': 0.18574286,
#  'learning_rate': 0.07910804}
# INFO:tensorflow:Step 4400 per-step time 0.522s
# I0815 17:04:10.007956 140400719425536 model_lib_v2.py:705] Step 4400 per-step time 0.522s
# INFO:tensorflow:{'Loss/classification_loss': 0.038545378,
#  'Loss/localization_loss': 0.015313084,
#  'Loss/regularization_loss': 0.12766483,
#  'Loss/total_loss': 0.1815233,
#  'learning_rate': 0.07905338}
# I0815 17:04:10.008410 140400719425536 model_lib_v2.py:708] {'Loss/classification_loss': 0.038545378,
#  'Loss/localization_loss': 0.015313084,
#  'Loss/regularization_loss': 0.12766483,
#  'Loss/total_loss': 0.1815233,
#  'learning_rate': 0.07905338}
# INFO:tensorflow:Step 4500 per-step time 0.542s
# I0815 17:05:04.217802 140400719425536 model_lib_v2.py:705] Step 4500 per-step time 0.542s
# INFO:tensorflow:{'Loss/classification_loss': 0.06273393,
#  'Loss/localization_loss': 0.020959873,
#  'Loss/regularization_loss': 0.12699917,
#  'Loss/total_loss': 0.21069297,
#  'learning_rate': 0.07899711}
# I0815 17:05:04.218165 140400719425536 model_lib_v2.py:708] {'Loss/classification_loss': 0.06273393,
#  'Loss/localization_loss': 0.020959873,
#  'Loss/regularization_loss': 0.12699917,
#  'Loss/total_loss': 0.21069297,
#  'learning_rate': 0.07899711}
# INFO:tensorflow:Step 4600 per-step time 0.553s
# I0815 17:05:59.508951 140400719425536 model_lib_v2.py:705] Step 4600 per-step time 0.553s
# INFO:tensorflow:{'Loss/classification_loss': 0.069318965,
#  'Loss/localization_loss': 0.017307172,
#  'Loss/regularization_loss': 0.12630899,
#  'Loss/total_loss': 0.21293513,
#  'learning_rate': 0.078939244}
# I0815 17:05:59.509337 140400719425536 model_lib_v2.py:708] {'Loss/classification_loss': 0.069318965,
#  'Loss/localization_loss': 0.017307172,
#  'Loss/regularization_loss': 0.12630899,
#  'Loss/total_loss': 0.21293513,
#  'learning_rate': 0.078939244}
# INFO:tensorflow:Step 4700 per-step time 0.552s
# I0815 17:06:54.659554 140400719425536 model_lib_v2.py:705] Step 4700 per-step time 0.552s
# INFO:tensorflow:{'Loss/classification_loss': 0.025539586,
#  'Loss/localization_loss': 0.008393202,
#  'Loss/regularization_loss': 0.12561898,
#  'Loss/total_loss': 0.15955177,
#  'learning_rate': 0.07887978}
# I0815 17:06:54.659886 140400719425536 model_lib_v2.py:708] {'Loss/classification_loss': 0.025539586,
#  'Loss/localization_loss': 0.008393202,
#  'Loss/regularization_loss': 0.12561898,
#  'Loss/total_loss': 0.15955177,
#  'learning_rate': 0.07887978}
# INFO:tensorflow:Step 4800 per-step time 0.524s
# I0815 17:07:47.053920 140400719425536 model_lib_v2.py:705] Step 4800 per-step time 0.524s
# INFO:tensorflow:{'Loss/classification_loss': 0.039610133,
#  'Loss/localization_loss': 0.008789206,
#  'Loss/regularization_loss': 0.12492556,
#  'Loss/total_loss': 0.17332491,
#  'learning_rate': 0.07881871}
# I0815 17:07:47.054316 140400719425536 model_lib_v2.py:708] {'Loss/classification_loss': 0.039610133,
#  'Loss/localization_loss': 0.008789206,
#  'Loss/regularization_loss': 0.12492556,
#  'Loss/total_loss': 0.17332491,
#  'learning_rate': 0.07881871}
# INFO:tensorflow:Step 4900 per-step time 0.539s
# I0815 17:08:40.991719 140400719425536 model_lib_v2.py:705] Step 4900 per-step time 0.539s
# INFO:tensorflow:{'Loss/classification_loss': 0.038328454,
#  'Loss/localization_loss': 0.011038297,
#  'Loss/regularization_loss': 0.124398924,
#  'Loss/total_loss': 0.17376567,
#  'learning_rate': 0.07875605}
# I0815 17:08:40.992071 140400719425536 model_lib_v2.py:708] {'Loss/classification_loss': 0.038328454,
#  'Loss/localization_loss': 0.011038297,
#  'Loss/regularization_loss': 0.124398924,
#  'Loss/total_loss': 0.17376567,
#  'learning_rate': 0.07875605}
# INFO:tensorflow:Step 5000 per-step time 0.600s
# I0815 17:09:40.947930 140400719425536 model_lib_v2.py:705] Step 5000 per-step time 0.600s
# INFO:tensorflow:{'Loss/classification_loss': 0.053428765,
#  'Loss/localization_loss': 0.01543961,
#  'Loss/regularization_loss': 0.123821996,
#  'Loss/total_loss': 0.19269037,
#  'learning_rate': 0.078691795}
# I0815 17:09:40.948360 140400719425536 model_lib_v2.py:708] {'Loss/classification_loss': 0.053428765,
#  'Loss/localization_loss': 0.01543961,
#  'Loss/regularization_loss': 0.123821996,
#  'Loss/total_loss': 0.19269037,
#  'learning_rate': 0.078691795}
# INFO:tensorflow:Step 5100 per-step time 0.630s
# I0815 17:10:43.957085 140400719425536 model_lib_v2.py:705] Step 5100 per-step time 0.630s
# INFO:tensorflow:{'Loss/classification_loss': 0.03862472,
#  'Loss/localization_loss': 0.0128131425,
#  'Loss/regularization_loss': 0.12315931,
#  'Loss/total_loss': 0.17459716,
#  'learning_rate': 0.07862595}
# I0815 17:10:43.957444 140400719425536 model_lib_v2.py:708] {'Loss/classification_loss': 0.03862472,
#  'Loss/localization_loss': 0.0128131425,
#  'Loss/regularization_loss': 0.12315931,
#  'Loss/total_loss': 0.17459716,
#  'learning_rate': 0.07862595}
# INFO:tensorflow:Step 5200 per-step time 0.555s
# I0815 17:11:39.501912 140400719425536 model_lib_v2.py:705] Step 5200 per-step time 0.555s
# INFO:tensorflow:{'Loss/classification_loss': 0.024757937,
#  'Loss/localization_loss': 0.009363258,
#  'Loss/regularization_loss': 0.12249638,
#  'Loss/total_loss': 0.15661758,
#  'learning_rate': 0.07855851}
# I0815 17:11:39.502323 140400719425536 model_lib_v2.py:708] {'Loss/classification_loss': 0.024757937,
#  'Loss/localization_loss': 0.009363258,
#  'Loss/regularization_loss': 0.12249638,
#  'Loss/total_loss': 0.15661758,
#  'learning_rate': 0.07855851}
# INFO:tensorflow:Step 5300 per-step time 0.530s
# I0815 17:12:32.471384 140400719425536 model_lib_v2.py:705] Step 5300 per-step time 0.530s
# INFO:tensorflow:{'Loss/classification_loss': 0.04282454,
#  'Loss/localization_loss': 0.01682114,
#  'Loss/regularization_loss': 0.121859886,
#  'Loss/total_loss': 0.18150556,
#  'learning_rate': 0.07848949}
# I0815 17:12:32.471705 140400719425536 model_lib_v2.py:708] {'Loss/classification_loss': 0.04282454,
#  'Loss/localization_loss': 0.01682114,
#  'Loss/regularization_loss': 0.121859886,
#  'Loss/total_loss': 0.18150556,
#  'learning_rate': 0.07848949}
# INFO:tensorflow:Step 5400 per-step time 0.535s
# I0815 17:13:26.012146 140400719425536 model_lib_v2.py:705] Step 5400 per-step time 0.535s
# INFO:tensorflow:{'Loss/classification_loss': 0.09712329,
#  'Loss/localization_loss': 0.017437665,
#  'Loss/regularization_loss': 0.12135468,
#  'Loss/total_loss': 0.23591563,
#  'learning_rate': 0.078418896}
# I0815 17:13:26.012533 140400719425536 model_lib_v2.py:708] {'Loss/classification_loss': 0.09712329,
#  'Loss/localization_loss': 0.017437665,
#  'Loss/regularization_loss': 0.12135468,
#  'Loss/total_loss': 0.23591563,
#  'learning_rate': 0.078418896}
# INFO:tensorflow:Step 5500 per-step time 0.551s
# I0815 17:14:21.119436 140400719425536 model_lib_v2.py:705] Step 5500 per-step time 0.551s
# INFO:tensorflow:{'Loss/classification_loss': 0.0379149,
#  'Loss/localization_loss': 0.01596867,
#  'Loss/regularization_loss': 0.120919526,
#  'Loss/total_loss': 0.1748031,
#  'learning_rate': 0.078346714}
# I0815 17:14:21.119767 140400719425536 model_lib_v2.py:708] {'Loss/classification_loss': 0.0379149,
#  'Loss/localization_loss': 0.01596867,
#  'Loss/regularization_loss': 0.120919526,
#  'Loss/total_loss': 0.1748031,
#  'learning_rate': 0.078346714}
# INFO:tensorflow:Step 5600 per-step time 0.544s
# I0815 17:15:15.516144 140400719425536 model_lib_v2.py:705] Step 5600 per-step time 0.544s
# INFO:tensorflow:{'Loss/classification_loss': 0.049041186,
#  'Loss/localization_loss': 0.009618412,
#  'Loss/regularization_loss': 0.12033804,
#  'Loss/total_loss': 0.17899764,
#  'learning_rate': 0.07827295}
# I0815 17:15:15.516529 140400719425536 model_lib_v2.py:708] {'Loss/classification_loss': 0.049041186,
#  'Loss/localization_loss': 0.009618412,
#  'Loss/regularization_loss': 0.12033804,
#  'Loss/total_loss': 0.17899764,
#  'learning_rate': 0.07827295}
# INFO:tensorflow:Step 5700 per-step time 0.536s
# I0815 17:16:09.147166 140400719425536 model_lib_v2.py:705] Step 5700 per-step time 0.536s
# INFO:tensorflow:{'Loss/classification_loss': 0.023315826,
#  'Loss/localization_loss': 0.00915821,
#  'Loss/regularization_loss': 0.11979893,
#  'Loss/total_loss': 0.15227297,
#  'learning_rate': 0.07819763}
# I0815 17:16:09.147586 140400719425536 model_lib_v2.py:708] {'Loss/classification_loss': 0.023315826,
#  'Loss/localization_loss': 0.00915821,
#  'Loss/regularization_loss': 0.11979893,
#  'Loss/total_loss': 0.15227297,
#  'learning_rate': 0.07819763}
# INFO:tensorflow:Step 5800 per-step time 0.538s
# I0815 17:17:02.946632 140400719425536 model_lib_v2.py:705] Step 5800 per-step time 0.538s
# INFO:tensorflow:{'Loss/classification_loss': 0.051014934,
#  'Loss/localization_loss': 0.015482255,
#  'Loss/regularization_loss': 0.119155444,
#  'Loss/total_loss': 0.18565264,
#  'learning_rate': 0.07812072}
# I0815 17:17:02.946993 140400719425536 model_lib_v2.py:708] {'Loss/classification_loss': 0.051014934,
#  'Loss/localization_loss': 0.015482255,
#  'Loss/regularization_loss': 0.119155444,
#  'Loss/total_loss': 0.18565264,
#  'learning_rate': 0.07812072}
# INFO:tensorflow:Step 5900 per-step time 0.543s
# I0815 17:17:57.263142 140400719425536 model_lib_v2.py:705] Step 5900 per-step time 0.543s
# INFO:tensorflow:{'Loss/classification_loss': 0.06715234,
#  'Loss/localization_loss': 0.02564324,
#  'Loss/regularization_loss': 0.118508115,
#  'Loss/total_loss': 0.2113037,
#  'learning_rate': 0.078042254}
# I0815 17:17:57.263537 140400719425536 model_lib_v2.py:708] {'Loss/classification_loss': 0.06715234,
#  'Loss/localization_loss': 0.02564324,
#  'Loss/regularization_loss': 0.118508115,
#  'Loss/total_loss': 0.2113037,
#  'learning_rate': 0.078042254}
# INFO:tensorflow:Step 6000 per-step time 0.546s
# I0815 17:18:51.877428 140400719425536 model_lib_v2.py:705] Step 6000 per-step time 0.546s
# INFO:tensorflow:{'Loss/classification_loss': 0.054405943,
#  'Loss/localization_loss': 0.01092239,
#  'Loss/regularization_loss': 0.1182123,
#  'Loss/total_loss': 0.18354063,
#  'learning_rate': 0.07796223}
# I0815 17:18:51.888929 140400719425536 model_lib_v2.py:708] {'Loss/classification_loss': 0.054405943,
#  'Loss/localization_loss': 0.01092239,
#  'Loss/regularization_loss': 0.1182123,
#  'Loss/total_loss': 0.18354063,
#  'learning_rate': 0.07796223}
# INFO:tensorflow:Step 6100 per-step time 0.528s
# I0815 17:19:44.633113 140400719425536 model_lib_v2.py:705] Step 6100 per-step time 0.528s
# INFO:tensorflow:{'Loss/classification_loss': 0.04598718,
#  'Loss/localization_loss': 0.0133473445,
#  'Loss/regularization_loss': 0.11764018,
#  'Loss/total_loss': 0.17697471,
#  'learning_rate': 0.077880636}
# I0815 17:19:44.633522 140400719425536 model_lib_v2.py:708] {'Loss/classification_loss': 0.04598718,
#  'Loss/localization_loss': 0.0133473445,
#  'Loss/regularization_loss': 0.11764018,
#  'Loss/total_loss': 0.17697471,
#  'learning_rate': 0.077880636}
# INFO:tensorflow:Step 6200 per-step time 0.537s
# I0815 17:20:38.337080 140400719425536 model_lib_v2.py:705] Step 6200 per-step time 0.537s
# INFO:tensorflow:{'Loss/classification_loss': 0.050826997,
#  'Loss/localization_loss': 0.01907001,
#  'Loss/regularization_loss': 0.11700575,
#  'Loss/total_loss': 0.18690276,
#  'learning_rate': 0.07779749}
# I0815 17:20:38.337421 140400719425536 model_lib_v2.py:708] {'Loss/classification_loss': 0.050826997,
#  'Loss/localization_loss': 0.01907001,
#  'Loss/regularization_loss': 0.11700575,
#  'Loss/total_loss': 0.18690276,
#  'learning_rate': 0.07779749}
# INFO:tensorflow:Step 6300 per-step time 0.543s
# I0815 17:21:32.622143 140400719425536 model_lib_v2.py:705] Step 6300 per-step time 0.543s
# INFO:tensorflow:{'Loss/classification_loss': 0.050262984,
#  'Loss/localization_loss': 0.019854818,
#  'Loss/regularization_loss': 0.11638659,
#  'Loss/total_loss': 0.1865044,
#  'learning_rate': 0.07771279}
# I0815 17:21:32.622687 140400719425536 model_lib_v2.py:708] {'Loss/classification_loss': 0.050262984,
#  'Loss/localization_loss': 0.019854818,
#  'Loss/regularization_loss': 0.11638659,
#  'Loss/total_loss': 0.1865044,
#  'learning_rate': 0.07771279}
# INFO:tensorflow:Step 6400 per-step time 0.545s
# I0815 17:22:27.126806 140400719425536 model_lib_v2.py:705] Step 6400 per-step time 0.545s
# INFO:tensorflow:{'Loss/classification_loss': 0.04274059,
#  'Loss/localization_loss': 0.0073337774,
#  'Loss/regularization_loss': 0.11576722,
#  'Loss/total_loss': 0.16584158,
#  'learning_rate': 0.077626534}
# I0815 17:22:27.127141 140400719425536 model_lib_v2.py:708] {'Loss/classification_loss': 0.04274059,
#  'Loss/localization_loss': 0.0073337774,
#  'Loss/regularization_loss': 0.11576722,
#  'Loss/total_loss': 0.16584158,
#  'learning_rate': 0.077626534}
# INFO:tensorflow:Step 6500 per-step time 0.550s
# I0815 17:23:22.113794 140400719425536 model_lib_v2.py:705] Step 6500 per-step time 0.550s
# INFO:tensorflow:{'Loss/classification_loss': 0.03743349,
#  'Loss/localization_loss': 0.01322577,
#  'Loss/regularization_loss': 0.115144536,
#  'Loss/total_loss': 0.16580379,
#  'learning_rate': 0.077538736}
# I0815 17:23:22.114176 140400719425536 model_lib_v2.py:708] {'Loss/classification_loss': 0.03743349,
#  'Loss/localization_loss': 0.01322577,
#  'Loss/regularization_loss': 0.115144536,
#  'Loss/total_loss': 0.16580379,
#  'learning_rate': 0.077538736}
# INFO:tensorflow:Step 6600 per-step time 0.626s
# I0815 17:24:24.722639 140400719425536 model_lib_v2.py:705] Step 6600 per-step time 0.626s
# INFO:tensorflow:{'Loss/classification_loss': 0.023585577,
#  'Loss/localization_loss': 0.008271697,
#  'Loss/regularization_loss': 0.11451073,
#  'Loss/total_loss': 0.146368,
#  'learning_rate': 0.07744939}
# I0815 17:24:24.723002 140400719425536 model_lib_v2.py:708] {'Loss/classification_loss': 0.023585577,
#  'Loss/localization_loss': 0.008271697,
#  'Loss/regularization_loss': 0.11451073,
#  'Loss/total_loss': 0.146368,
#  'learning_rate': 0.07744939}
# INFO:tensorflow:Step 6700 per-step time 0.545s
# I0815 17:25:19.271431 140400719425536 model_lib_v2.py:705] Step 6700 per-step time 0.545s
# INFO:tensorflow:{'Loss/classification_loss': 0.026485613,
#  'Loss/localization_loss': 0.0065147486,
#  'Loss/regularization_loss': 0.113911785,
#  'Loss/total_loss': 0.14691214,
#  'learning_rate': 0.077358514}
# I0815 17:25:19.271800 140400719425536 model_lib_v2.py:708] {'Loss/classification_loss': 0.026485613,
#  'Loss/localization_loss': 0.0065147486,
#  'Loss/regularization_loss': 0.113911785,
#  'Loss/total_loss': 0.14691214,
#  'learning_rate': 0.077358514}
# INFO:tensorflow:Step 6800 per-step time 0.537s
# I0815 17:26:12.961169 140400719425536 model_lib_v2.py:705] Step 6800 per-step time 0.537s
# INFO:tensorflow:{'Loss/classification_loss': 0.054373085,
#  'Loss/localization_loss': 0.02573174,
#  'Loss/regularization_loss': 0.11328386,
#  'Loss/total_loss': 0.19338869,
#  'learning_rate': 0.0772661}
# I0815 17:26:12.961544 140400719425536 model_lib_v2.py:708] {'Loss/classification_loss': 0.054373085,
#  'Loss/localization_loss': 0.02573174,
#  'Loss/regularization_loss': 0.11328386,
#  'Loss/total_loss': 0.19338869,
#  'learning_rate': 0.0772661}
# INFO:tensorflow:Step 6900 per-step time 0.532s
# I0815 17:27:06.174282 140400719425536 model_lib_v2.py:705] Step 6900 per-step time 0.532s
# INFO:tensorflow:{'Loss/classification_loss': 0.08456475,
#  'Loss/localization_loss': 0.010250249,
#  'Loss/regularization_loss': 0.11271661,
#  'Loss/total_loss': 0.20753162,
#  'learning_rate': 0.077172145}
# I0815 17:27:06.174618 140400719425536 model_lib_v2.py:708] {'Loss/classification_loss': 0.08456475,
#  'Loss/localization_loss': 0.010250249,
#  'Loss/regularization_loss': 0.11271661,
#  'Loss/total_loss': 0.20753162,
#  'learning_rate': 0.077172145}
# INFO:tensorflow:Step 7000 per-step time 0.544s
# I0815 17:28:00.583342 140400719425536 model_lib_v2.py:705] Step 7000 per-step time 0.544s
# ...
# I0815 17:30:43.842431 140400719425536 model_lib_v2.py:708] {'Loss/classification_loss': 0.028023934,
#  'Loss/localization_loss': 0.0066596987,
#  'Loss/regularization_loss': 0.11029758,
#  'Loss/total_loss': 0.14498122,
#  'learning_rate': 0.07678111}
# INFO:tensorflow:Step 7400 per-step time 0.526s
# I0815 17:31:36.407563 140400719425536 model_lib_v2.py:705] Step 7400 per-step time 0.526s
# INFO:tensorflow:{'Loss/classification_loss': 0.03469884,
#  'Loss/localization_loss': 0.0060674883,
#  'Loss/regularization_loss': 0.10970106,
#  'Loss/total_loss': 0.15046738,
#  'learning_rate': 0.076679565}
# I0815 17:31:36.407997 140400719425536 model_lib_v2.py:708] {'Loss/classification_loss': 0.03469884,
#  'Loss/localization_loss': 0.0060674883,
#  'Loss/regularization_loss': 0.10970106,
#  'Loss/total_loss': 0.15046738,
#  'learning_rate': 0.076679565}
# INFO:tensorflow:Step 7500 per-step time 0.548s
# I0815 17:32:31.177817 140400719425536 model_lib_v2.py:705] Step 7500 per-step time 0.548s
# INFO:tensorflow:{'Loss/classification_loss': 0.030365054,
#  'Loss/localization_loss': 0.009460286,
#  'Loss/regularization_loss': 0.10912192,
#  'Loss/total_loss': 0.14894725,
#  'learning_rate': 0.0765765}
# I0815 17:32:31.178170 140400719425536 model_lib_v2.py:708] {'Loss/classification_loss': 0.030365054,
#  'Loss/localization_loss': 0.009460286,
#  'Loss/regularization_loss': 0.10912192,
#  'Loss/total_loss': 0.14894725,
#  'learning_rate': 0.0765765}
# INFO:tensorflow:Step 7600 per-step time 0.547s
# I0815 17:33:25.880964 140400719425536 model_lib_v2.py:705] Step 7600 per-step time 0.547s
# INFO:tensorflow:{'Loss/classification_loss': 0.04011137,
#  'Loss/localization_loss': 0.013040148,
#  'Loss/regularization_loss': 0.10853173,
#  'Loss/total_loss': 0.16168326,
#  'learning_rate': 0.07647194}
# I0815 17:33:25.881322 140400719425536 model_lib_v2.py:708] {'Loss/classification_loss': 0.04011137,
#  'Loss/localization_loss': 0.013040148,
#  'Loss/regularization_loss': 0.10853173,
#  'Loss/total_loss': 0.16168326,
#  'learning_rate': 0.07647194}
# INFO:tensorflow:Step 7700 per-step time 0.556s
# I0815 17:34:21.508956 140400719425536 model_lib_v2.py:705] Step 7700 per-step time 0.556s
# INFO:tensorflow:{'Loss/classification_loss': 0.036103416,
#  'Loss/localization_loss': 0.021965105,
#  'Loss/regularization_loss': 0.107966304,
#  'Loss/total_loss': 0.16603482,
#  'learning_rate': 0.07636588}
# I0815 17:34:21.509354 140400719425536 model_lib_v2.py:708] {'Loss/classification_loss': 0.036103416,
#  'Loss/localization_loss': 0.021965105,
#  'Loss/regularization_loss': 0.107966304,
#  'Loss/total_loss': 0.16603482,
#  'learning_rate': 0.07636588}
# INFO:tensorflow:Step 7800 per-step time 0.532s
# I0815 17:35:14.749006 140400719425536 model_lib_v2.py:705] Step 7800 per-step time 0.532s
# INFO:tensorflow:{'Loss/classification_loss': 0.038101457,
#  'Loss/localization_loss': 0.018093528,
#  'Loss/regularization_loss': 0.107382976,
#  'Loss/total_loss': 0.16357796,
#  'learning_rate': 0.07625833}
# I0815 17:35:14.749380 140400719425536 model_lib_v2.py:708] {'Loss/classification_loss': 0.038101457,
#  'Loss/localization_loss': 0.018093528,
#  'Loss/regularization_loss': 0.107382976,
#  'Loss/total_loss': 0.16357796,
#  'learning_rate': 0.07625833}
# INFO:tensorflow:Step 7900 per-step time 0.552s
# I0815 17:36:09.929581 140400719425536 model_lib_v2.py:705] Step 7900 per-step time 0.552s
# INFO:tensorflow:{'Loss/classification_loss': 0.023966521,
#  'Loss/localization_loss': 0.013553048,
#  'Loss/regularization_loss': 0.107027985,
#  'Loss/total_loss': 0.14454755,
#  'learning_rate': 0.07614928}
# I0815 17:36:09.929944 140400719425536 model_lib_v2.py:708] {'Loss/classification_loss': 0.023966521,
#  'Loss/localization_loss': 0.013553048,
#  'Loss/regularization_loss': 0.107027985,
#  'Loss/total_loss': 0.14454755,
#  'learning_rate': 0.07614928}
# INFO:tensorflow:Step 8000 per-step time 0.554s
# I0815 17:37:05.276784 140400719425536 model_lib_v2.py:705] Step 8000 per-step time 0.554s
# INFO:tensorflow:{'Loss/classification_loss': 0.03513608,
#  'Loss/localization_loss': 0.008930502,
#  'Loss/regularization_loss': 0.10659013,
#  'Loss/total_loss': 0.15065672,
#  'learning_rate': 0.07603875}
# I0815 17:37:05.277158 140400719425536 model_lib_v2.py:708] {'Loss/classification_loss': 0.03513608,
#  'Loss/localization_loss': 0.008930502,
#  'Loss/regularization_loss': 0.10659013,
#  'Loss/total_loss': 0.15065672,
#  'learning_rate': 0.07603875}
# INFO:tensorflow:Step 8100 per-step time 0.548s
# I0815 17:38:00.079703 140400719425536 model_lib_v2.py:705] Step 8100 per-step time 0.548s
# INFO:tensorflow:{'Loss/classification_loss': 0.044126447,
#  'Loss/localization_loss': 0.01860822,
#  'Loss/regularization_loss': 0.106027156,
#  'Loss/total_loss': 0.16876182,
#  'learning_rate': 0.07592674}
# I0815 17:38:00.080168 140400719425536 model_lib_v2.py:708] {'Loss/classification_loss': 0.044126447,
#  'Loss/localization_loss': 0.01860822,
#  'Loss/regularization_loss': 0.106027156,
#  'Loss/total_loss': 0.16876182,
#  'learning_rate': 0.07592674}
# INFO:tensorflow:Step 8200 per-step time 0.526s
# I0815 17:38:52.640444 140400719425536 model_lib_v2.py:705] Step 8200 per-step time 0.526s
# INFO:tensorflow:{'Loss/classification_loss': 0.023447014,
#  'Loss/localization_loss': 0.0055748424,
#  'Loss/regularization_loss': 0.10547723,
#  'Loss/total_loss': 0.13449909,
#  'learning_rate': 0.075813256}
# I0815 17:38:52.640773 140400719425536 model_lib_v2.py:708] {'Loss/classification_loss': 0.023447014,
#  'Loss/localization_loss': 0.0055748424,
#  'Loss/regularization_loss': 0.10547723,
#  'Loss/total_loss': 0.13449909,
#  'learning_rate': 0.075813256}
# INFO:tensorflow:Step 8300 per-step time 0.546s
# I0815 17:39:47.188176 140400719425536 model_lib_v2.py:705] Step 8300 per-step time 0.546s
# INFO:tensorflow:{'Loss/classification_loss': 0.03471121,
#  'Loss/localization_loss': 0.12819727,
#  'Loss/regularization_loss': 0.10494097,
#  'Loss/total_loss': 0.26784945,
#  'learning_rate': 0.07569829}
# I0815 17:39:47.188566 140400719425536 model_lib_v2.py:708] {'Loss/classification_loss': 0.03471121,
#  'Loss/localization_loss': 0.12819727,
#  'Loss/regularization_loss': 0.10494097,
#  'Loss/total_loss': 0.26784945,
#  'learning_rate': 0.07569829}
# INFO:tensorflow:Step 8400 per-step time 0.640s
# I0815 17:40:51.203766 140400719425536 model_lib_v2.py:705] Step 8400 per-step time 0.640s
# INFO:tensorflow:{'Loss/classification_loss': 0.04260612,
#  'Loss/localization_loss': 0.01384942,
#  'Loss/regularization_loss': 0.104395404,
#  'Loss/total_loss': 0.16085094,
#  'learning_rate': 0.07558186}
# I0815 17:40:51.204108 140400719425536 model_lib_v2.py:708] {'Loss/classification_loss': 0.04260612,
#  'Loss/localization_loss': 0.01384942,
#  'Loss/regularization_loss': 0.104395404,
#  'Loss/total_loss': 0.16085094,
#  'learning_rate': 0.07558186}
# INFO:tensorflow:Step 8500 per-step time 0.631s
# I0815 17:41:54.271135 140400719425536 model_lib_v2.py:705] Step 8500 per-step time 0.631s
# INFO:tensorflow:{'Loss/classification_loss': 0.022485554,
#  'Loss/localization_loss': 0.004115409,
#  'Loss/regularization_loss': 0.10384827,
#  'Loss/total_loss': 0.13044924,
#  'learning_rate': 0.07546397}
# I0815 17:41:54.271706 140400719425536 model_lib_v2.py:708] {'Loss/classification_loss': 0.022485554,
#  'Loss/localization_loss': 0.004115409,
#  'Loss/regularization_loss': 0.10384827,
#  'Loss/total_loss': 0.13044924,
#  'learning_rate': 0.07546397}
# INFO:tensorflow:Step 8600 per-step time 0.618s
# I0815 17:42:56.103165 140400719425536 model_lib_v2.py:705] Step 8600 per-step time 0.618s
# INFO:tensorflow:{'Loss/classification_loss': 0.058956467,
#  'Loss/localization_loss': 0.0143163325,
#  'Loss/regularization_loss': 0.10328785,
#  'Loss/total_loss': 0.17656066,
#  'learning_rate': 0.075344615}
# I0815 17:42:56.103693 140400719425536 model_lib_v2.py:708] {'Loss/classification_loss': 0.058956467,
#  'Loss/localization_loss': 0.0143163325,
#  'Loss/regularization_loss': 0.10328785,
#  'Loss/total_loss': 0.17656066,
#  'learning_rate': 0.075344615}
# INFO:tensorflow:Step 8700 per-step time 0.537s
# I0815 17:43:49.825734 140400719425536 model_lib_v2.py:705] Step 8700 per-step time 0.537s
# INFO:tensorflow:{'Loss/classification_loss': 0.026350139,
#  'Loss/localization_loss': 0.006919015,
#  'Loss/regularization_loss': 0.102755345,
#  'Loss/total_loss': 0.13602449,
#  'learning_rate': 0.07522382}
# I0815 17:43:49.826127 140400719425536 model_lib_v2.py:708] {'Loss/classification_loss': 0.026350139,
#  'Loss/localization_loss': 0.006919015,
#  'Loss/regularization_loss': 0.102755345,
#  'Loss/total_loss': 0.13602449,
#  'learning_rate': 0.07522382}
# INFO:tensorflow:Step 8800 per-step time 0.560s
# I0815 17:44:45.838062 140400719425536 model_lib_v2.py:705] Step 8800 per-step time 0.560s
# INFO:tensorflow:{'Loss/classification_loss': 0.034625266,
#  'Loss/localization_loss': 0.005644794,
#  'Loss/regularization_loss': 0.10222875,
#  'Loss/total_loss': 0.14249882,
#  'learning_rate': 0.07510157}
# I0815 17:44:45.838397 140400719425536 model_lib_v2.py:708] {'Loss/classification_loss': 0.034625266,
#  'Loss/localization_loss': 0.005644794,
#  'Loss/regularization_loss': 0.10222875,
#  'Loss/total_loss': 0.14249882,
#  'learning_rate': 0.07510157}
# INFO:tensorflow:Step 8900 per-step time 0.566s
# I0815 17:45:42.475118 140400719425536 model_lib_v2.py:705] Step 8900 per-step time 0.566s
# INFO:tensorflow:{'Loss/classification_loss': 0.033171874,
#  'Loss/localization_loss': 0.009918478,
#  'Loss/regularization_loss': 0.10168201,
#  'Loss/total_loss': 0.14477235,
#  'learning_rate': 0.074977875}
# I0815 17:45:42.475554 140400719425536 model_lib_v2.py:708] {'Loss/classification_loss': 0.033171874,
#  'Loss/localization_loss': 0.009918478,
#  'Loss/regularization_loss': 0.10168201,
#  'Loss/total_loss': 0.14477235,
#  'learning_rate': 0.074977875}
# INFO:tensorflow:Step 9000 per-step time 0.587s
# I0815 17:46:41.213946 140400719425536 model_lib_v2.py:705] Step 9000 per-step time 0.587s
# INFO:tensorflow:{'Loss/classification_loss': 0.054650098,
#  'Loss/localization_loss': 0.014982803,
#  'Loss/regularization_loss': 0.10114108,
#  'Loss/total_loss': 0.17077398,
#  'learning_rate': 0.07485275}
# I0815 17:46:41.214423 140400719425536 model_lib_v2.py:708] {'Loss/classification_loss': 0.054650098,
#  'Loss/localization_loss': 0.014982803,
#  'Loss/regularization_loss': 0.10114108,
#  'Loss/total_loss': 0.17077398,
#  'learning_rate': 0.07485275}
# INFO:tensorflow:Step 9100 per-step time 0.539s
# I0815 17:47:35.069540 140400719425536 model_lib_v2.py:705] Step 9100 per-step time 0.539s
# INFO:tensorflow:{'Loss/classification_loss': 0.04320044,
#  'Loss/localization_loss': 0.008920921,
#  'Loss/regularization_loss': 0.10062691,
#  'Loss/total_loss': 0.15274827,
#  'learning_rate': 0.07472619}
# I0815 17:47:35.069958 140400719425536 model_lib_v2.py:708] {'Loss/classification_loss': 0.04320044,
#  'Loss/localization_loss': 0.008920921,
#  'Loss/regularization_loss': 0.10062691,
#  'Loss/total_loss': 0.15274827,
#  'learning_rate': 0.07472619}
# INFO:tensorflow:Step 9200 per-step time 0.540s
# I0815 17:48:29.059944 140400719425536 model_lib_v2.py:705] Step 9200 per-step time 0.540s
# INFO:tensorflow:{'Loss/classification_loss': 0.031891245,
#  'Loss/localization_loss': 0.0056504915,
#  'Loss/regularization_loss': 0.10010282,
#  'Loss/total_loss': 0.13764456,
#  'learning_rate': 0.07459819}
# I0815 17:48:29.060306 140400719425536 model_lib_v2.py:708] {'Loss/classification_loss': 0.031891245,
#  'Loss/localization_loss': 0.0056504915,
#  'Loss/regularization_loss': 0.10010282,
#  'Loss/total_loss': 0.13764456,
#  'learning_rate': 0.07459819}
# INFO:tensorflow:Step 9300 per-step time 0.547s
# I0815 17:49:23.793997 140400719425536 model_lib_v2.py:705] Step 9300 per-step time 0.547s
# INFO:tensorflow:{'Loss/classification_loss': 0.044587284,
#  'Loss/localization_loss': 0.009084912,
#  'Loss/regularization_loss': 0.09958854,
#  'Loss/total_loss': 0.15326074,
#  'learning_rate': 0.074468784}
# I0815 17:49:23.794386 140400719425536 model_lib_v2.py:708] {'Loss/classification_loss': 0.044587284,
#  'Loss/localization_loss': 0.009084912,
#  'Loss/regularization_loss': 0.09958854,
#  'Loss/total_loss': 0.15326074,
#  'learning_rate': 0.074468784}
# INFO:tensorflow:Step 9400 per-step time 0.516s
# I0815 17:50:15.358355 140400719425536 model_lib_v2.py:705] Step 9400 per-step time 0.516s
# INFO:tensorflow:{'Loss/classification_loss': 0.026640868,
#  'Loss/localization_loss': 0.0053483364,
#  'Loss/regularization_loss': 0.09910595,
#  'Loss/total_loss': 0.13109516,
#  'learning_rate': 0.074337944}
# I0815 17:50:15.358698 140400719425536 model_lib_v2.py:708] {'Loss/classification_loss': 0.026640868,
#  'Loss/localization_loss': 0.0053483364,
#  'Loss/regularization_loss': 0.09910595,
#  'Loss/total_loss': 0.13109516,
#  'learning_rate': 0.074337944}
# INFO:tensorflow:Step 9500 per-step time 0.531s
# I0815 17:51:08.449012 140400719425536 model_lib_v2.py:705] Step 9500 per-step time 0.531s
# INFO:tensorflow:{'Loss/classification_loss': 0.03674249,
#  'Loss/localization_loss': 0.01600472,
#  'Loss/regularization_loss': 0.09857059,
#  'Loss/total_loss': 0.1513178,
#  'learning_rate': 0.074205704}
# I0815 17:51:08.449373 140400719425536 model_lib_v2.py:708] {'Loss/classification_loss': 0.03674249,
#  'Loss/localization_loss': 0.01600472,
#  'Loss/regularization_loss': 0.09857059,
#  'Loss/total_loss': 0.1513178,
#  'learning_rate': 0.074205704}
# INFO:tensorflow:Step 9600 per-step time 0.543s
# I0815 17:52:02.757661 140400719425536 model_lib_v2.py:705] Step 9600 per-step time 0.543s
# INFO:tensorflow:{'Loss/classification_loss': 0.034739263,
#  'Loss/localization_loss': 0.009130668,
#  'Loss/regularization_loss': 0.09805221,
#  'Loss/total_loss': 0.14192215,
#  'learning_rate': 0.07407206}
# I0815 17:52:02.758031 140400719425536 model_lib_v2.py:708] {'Loss/classification_loss': 0.034739263,
#  'Loss/localization_loss': 0.009130668,
#  'Loss/regularization_loss': 0.09805221,
#  'Loss/total_loss': 0.14192215,
#  'learning_rate': 0.07407206}
# INFO:tensorflow:Step 9700 per-step time 0.546s
# I0815 17:52:57.394848 140400719425536 model_lib_v2.py:705] Step 9700 per-step time 0.546s
# INFO:tensorflow:{'Loss/classification_loss': 0.032281708,
#  'Loss/localization_loss': 0.005796101,
#  'Loss/regularization_loss': 0.09754239,
#  'Loss/total_loss': 0.1356202,
#  'learning_rate': 0.073937014}
# I0815 17:52:57.395203 140400719425536 model_lib_v2.py:708] {'Loss/classification_loss': 0.032281708,
#  'Loss/localization_loss': 0.005796101,
#  'Loss/regularization_loss': 0.09754239,
#  'Loss/total_loss': 0.1356202,
#  'learning_rate': 0.073937014}
# INFO:tensorflow:Step 9800 per-step time 0.509s
# I0815 17:53:48.381363 140400719425536 model_lib_v2.py:705] Step 9800 per-step time 0.509s
# INFO:tensorflow:{'Loss/classification_loss': 0.03400933,
#  'Loss/localization_loss': 0.006474082,
#  'Loss/regularization_loss': 0.09704774,
#  'Loss/total_loss': 0.13753115,
#  'learning_rate': 0.07380057}
# I0815 17:53:48.381734 140400719425536 model_lib_v2.py:708] {'Loss/classification_loss': 0.03400933,
#  'Loss/localization_loss': 0.006474082,
#  'Loss/regularization_loss': 0.09704774,
#  'Loss/total_loss': 0.13753115,
#  'learning_rate': 0.07380057}
# INFO:tensorflow:Step 9900 per-step time 0.539s
# I0815 17:54:42.236047 140400719425536 model_lib_v2.py:705] Step 9900 per-step time 0.539s
# INFO:tensorflow:{'Loss/classification_loss': 0.034357704,
#  'Loss/localization_loss': 0.009839906,
#  'Loss/regularization_loss': 0.096554466,
#  'Loss/total_loss': 0.14075208,
#  'learning_rate': 0.073662736}
# I0815 17:54:42.236434 140400719425536 model_lib_v2.py:708] {'Loss/classification_loss': 0.034357704,
#  'Loss/localization_loss': 0.009839906,
#  'Loss/regularization_loss': 0.096554466,
#  'Loss/total_loss': 0.14075208,
#  'learning_rate': 0.073662736}
# INFO:tensorflow:Step 10000 per-step time 0.546s
# I0815 17:55:36.846965 140400719425536 model_lib_v2.py:705] Step 10000 per-step time 0.546s
# INFO:tensorflow:{'Loss/classification_loss': 0.030024175,
#  'Loss/localization_loss': 0.0051918235,
#  'Loss/regularization_loss': 0.09605737,
#  'Loss/total_loss': 0.13127336,
#  'learning_rate': 0.07352352}
# I0815 17:55:36.847383 140400719425536 model_lib_v2.py:708] {'Loss/classification_loss': 0.030024175,
#  'Loss/localization_loss': 0.0051918235,
#  'Loss/regularization_loss': 0.09605737,
#  'Loss/total_loss': 0.13127336,
#  'learning_rate': 0.07352352}

# %%
import tensorflow as tf

from object_detection.utils import config_util
from object_detection.builders import model_builder
from object_detection.exporter import export_inference_graph

pipeline_config = pipeline_config_path
model_dir = "/content/drive/MyDrive/Woods_Hole_1_9_4"
output_directory = '/content/drive/MyDrive/Woods_Hole_1_9_4/exported_model'

# Build the model
configs = config_util.get_configs_from_pipeline_file(pipeline_config)
model_config = configs['model']
detection_model = model_builder.build(model_config=model_config, is_training=False)

# Restore the checkpoint
ckpt = tf.compat.v2.train.Checkpoint(model=detection_model)
ckpt.restore(os.path.join(model_dir, 'ckpt-11')).expect_partial()

# Export the saved model
export_inference_graph(input_type='image_tensor',
                       pipeline_config=pipeline_config,
                       trained_checkpoint_dir=model_dir,
                       output_directory=output_directory)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-11-c6143447e156> in <cell line: 21>()
#      19
#      20 # Export the saved model
# ---> 21 export_inference_graph(input_type='image_tensor',
#      22                        pipeline_config=pipeline_config,
#      23                        trained_checkpoint_dir=model_dir,
#
# TypeError: export_inference_graph() got an unexpected keyword argument 'trained_checkpoint_dir'

# %%
import os
from object_detection.utils import config_util
from object_detection.builders import model_builder
from object_detection.exporter import export_inference_graph

model_dir = '/content/drive/MyDrive/Woods_Hole_1_9_4'
pipeline_config_path = '/content/drive/MyDrive/Woods_Hole_1_9_4/ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8/pipeline.config'
trained_checkpoint_dir = model_dir
output_directory = '/content/exported_model'
# !python /content/models/research/object_detection/exporter_main_v2.py \
    --pipeline_config_path {pipeline_config_path} \
    --trained_checkpoint_dir {trained_checkpoint_dir} \
    --output_directory {output_directory}
# Out:
# 2023-08-15 18:35:45.275252: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# WARNING:tensorflow:From /usr/local/lib/python3.10/dist-packages/tensorflow/python/autograph/impl/api.py:459: calling map_fn_v2 (from tensorflow.python.ops.map_fn) with back_prop=False is deprecated and will be removed in a future version.
# Instructions for updating:
# back_prop=False is deprecated. Consider using tf.stop_gradient instead.
# Instead of:
# results = tf.map_fn(fn, elems, back_prop=False)
# Use:
# results = tf.nest.map_structure(tf.stop_gradient, tf.map_fn(fn, elems))
# W0815 18:35:51.224714 134095775469568 deprecation.py:641] From /usr/local/lib/python3.10/dist-packages/tensorflow/python/autograph/impl/api.py:459: calling map_fn_v2 (from tensorflow.python.ops.map_fn) with back_prop=False is deprecated and will be removed in a future version.
# Instructions for updating:
# back_prop=False is deprecated. Consider using tf.stop_gradient instead.
# Instead of:
# results = tf.map_fn(fn, elems, back_prop=False)
# Use:
# results = tf.nest.map_structure(tf.stop_gradient, tf.map_fn(fn, elems))
# I0815 18:35:55.833153 134095775469568 api.py:460] feature_map_spatial_dims: [(40, 40), (20, 20), (10, 10), (5, 5), (3, 3)]
# I0815 18:36:06.124674 134095775469568 api.py:460] feature_map_spatial_dims: [(40, 40), (20, 20), (10, 10), (5, 5), (3, 3)]
# I0815 18:36:08.911160 134095775469568 signature_serialization.py:148] Function `call_func` contains input name(s) resource with unsupported characters which will be renamed to weightsharedconvolutionalboxpredictor_predictiontower_conv2d_3_batchnorm_feature_4_fusedbatchnormv3_readvariableop_1_resource in the SavedModel.
# I0815 18:36:10.326648 134095775469568 api.py:460] feature_map_spatial_dims: [(40, 40), (20, 20), (10, 10), (5, 5), (3, 3)]
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.meta_architectures.ssd_meta_arch.SSDMetaArch object at 0x79f4748ecc40>, because it is not built.
# W0815 18:36:12.693405 134095775469568 save_impl.py:66] Skipping full serialization of Keras layer <object_detection.meta_architectures.ssd_meta_arch.SSDMetaArch object at 0x79f4748ecc40>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.src.layers.convolutional.separable_conv2d.SeparableConv2D object at 0x79f46c5e7490>, because it is not built.
# W0815 18:36:13.010092 134095775469568 save_impl.py:66] Skipping full serialization of Keras layer <keras.src.layers.convolutional.separable_conv2d.SeparableConv2D object at 0x79f46c5e7490>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x79f46c3639a0>, because it is not built.
# W0815 18:36:13.010344 134095775469568 save_impl.py:66] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x79f46c3639a0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.src.layers.core.lambda_layer.Lambda object at 0x79f46c3607c0>, because it is not built.
# W0815 18:36:13.010429 134095775469568 save_impl.py:66] Skipping full serialization of Keras layer <keras.src.layers.core.lambda_layer.Lambda object at 0x79f46c3607c0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.src.layers.convolutional.separable_conv2d.SeparableConv2D object at 0x79f46c1b9de0>, because it is not built.
# W0815 18:36:13.010499 134095775469568 save_impl.py:66] Skipping full serialization of Keras layer <keras.src.layers.convolutional.separable_conv2d.SeparableConv2D object at 0x79f46c1b9de0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x79f46c6e3070>, because it is not built.
# W0815 18:36:13.010562 134095775469568 save_impl.py:66] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x79f46c6e3070>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.src.layers.core.lambda_layer.Lambda object at 0x79f46c6e0d00>, because it is not built.
# W0815 18:36:13.010622 134095775469568 save_impl.py:66] Skipping full serialization of Keras layer <keras.src.layers.core.lambda_layer.Lambda object at 0x79f46c6e0d00>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.src.layers.convolutional.separable_conv2d.SeparableConv2D object at 0x79f46c6e1240>, because it is not built.
# W0815 18:36:13.010681 134095775469568 save_impl.py:66] Skipping full serialization of Keras layer <keras.src.layers.convolutional.separable_conv2d.SeparableConv2D object at 0x79f46c6e1240>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x79f46c6e0220>, because it is not built.
# W0815 18:36:13.010740 134095775469568 save_impl.py:66] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x79f46c6e0220>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.src.layers.core.lambda_layer.Lambda object at 0x79f46c6e1ab0>, because it is not built.
# W0815 18:36:13.010797 134095775469568 save_impl.py:66] Skipping full serialization of Keras layer <keras.src.layers.core.lambda_layer.Lambda object at 0x79f46c6e1ab0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.src.layers.convolutional.separable_conv2d.SeparableConv2D object at 0x79f46c6e2c80>, because it is not built.
# W0815 18:36:13.010861 134095775469568 save_impl.py:66] Skipping full serialization of Keras layer <keras.src.layers.convolutional.separable_conv2d.SeparableConv2D object at 0x79f46c6e2c80>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x79f46c6e2830>, because it is not built.
# W0815 18:36:13.010918 134095775469568 save_impl.py:66] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x79f46c6e2830>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.src.layers.core.lambda_layer.Lambda object at 0x79f46c6e2650>, because it is not built.
# W0815 18:36:13.010973 134095775469568 save_impl.py:66] Skipping full serialization of Keras layer <keras.src.layers.core.lambda_layer.Lambda object at 0x79f46c6e2650>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x79f46c6e3af0>, because it is not built.
# W0815 18:36:13.011038 134095775469568 save_impl.py:66] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x79f46c6e3af0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.src.layers.core.lambda_layer.Lambda object at 0x79f46c2fe080>, because it is not built.
# W0815 18:36:13.011097 134095775469568 save_impl.py:66] Skipping full serialization of Keras layer <keras.src.layers.core.lambda_layer.Lambda object at 0x79f46c2fe080>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x79f46c2fcd30>, because it is not built.
# W0815 18:36:13.011153 134095775469568 save_impl.py:66] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x79f46c2fcd30>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.src.layers.core.lambda_layer.Lambda object at 0x79f46c2fd720>, because it is not built.
# W0815 18:36:13.011220 134095775469568 save_impl.py:66] Skipping full serialization of Keras layer <keras.src.layers.core.lambda_layer.Lambda object at 0x79f46c2fd720>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x79f46c6d9e10>, because it is not built.
# W0815 18:36:13.011279 134095775469568 save_impl.py:66] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x79f46c6d9e10>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.src.layers.core.lambda_layer.Lambda object at 0x79f46c6db880>, because it is not built.
# W0815 18:36:13.011336 134095775469568 save_impl.py:66] Skipping full serialization of Keras layer <keras.src.layers.core.lambda_layer.Lambda object at 0x79f46c6db880>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x79f46c6da5c0>, because it is not built.
# W0815 18:36:13.011392 134095775469568 save_impl.py:66] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x79f46c6da5c0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.src.layers.core.lambda_layer.Lambda object at 0x79f46c6d9180>, because it is not built.
# W0815 18:36:13.011449 134095775469568 save_impl.py:66] Skipping full serialization of Keras layer <keras.src.layers.core.lambda_layer.Lambda object at 0x79f46c6d9180>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x79f46c6d98a0>, because it is not built.
# W0815 18:36:13.011505 134095775469568 save_impl.py:66] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x79f46c6d98a0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.src.layers.core.lambda_layer.Lambda object at 0x79f45079c040>, because it is not built.
# W0815 18:36:13.011563 134095775469568 save_impl.py:66] Skipping full serialization of Keras layer <keras.src.layers.core.lambda_layer.Lambda object at 0x79f45079c040>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x79f45079f100>, because it is not built.
# W0815 18:36:13.011620 134095775469568 save_impl.py:66] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x79f45079f100>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.src.layers.core.lambda_layer.Lambda object at 0x79f45079d150>, because it is not built.
# W0815 18:36:13.011677 134095775469568 save_impl.py:66] Skipping full serialization of Keras layer <keras.src.layers.core.lambda_layer.Lambda object at 0x79f45079d150>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x79f46c4bfe50>, because it is not built.
# W0815 18:36:13.011733 134095775469568 save_impl.py:66] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x79f46c4bfe50>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.src.layers.core.lambda_layer.Lambda object at 0x79f46c677940>, because it is not built.
# W0815 18:36:13.011789 134095775469568 save_impl.py:66] Skipping full serialization of Keras layer <keras.src.layers.core.lambda_layer.Lambda object at 0x79f46c677940>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x79f46c677340>, because it is not built.
# W0815 18:36:13.011850 134095775469568 save_impl.py:66] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x79f46c677340>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.src.layers.core.lambda_layer.Lambda object at 0x79f46c676d70>, because it is not built.
# W0815 18:36:13.011906 134095775469568 save_impl.py:66] Skipping full serialization of Keras layer <keras.src.layers.core.lambda_layer.Lambda object at 0x79f46c676d70>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x79f46c69ca60>, because it is not built.
# W0815 18:36:13.011963 134095775469568 save_impl.py:66] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x79f46c69ca60>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.src.layers.core.lambda_layer.Lambda object at 0x79f46c69da20>, because it is not built.
# W0815 18:36:13.012018 134095775469568 save_impl.py:66] Skipping full serialization of Keras layer <keras.src.layers.core.lambda_layer.Lambda object at 0x79f46c69da20>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x79f46c69fac0>, because it is not built.
# W0815 18:36:13.012075 134095775469568 save_impl.py:66] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x79f46c69fac0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.src.layers.core.lambda_layer.Lambda object at 0x79f46c69ddb0>, because it is not built.
# W0815 18:36:13.012131 134095775469568 save_impl.py:66] Skipping full serialization of Keras layer <keras.src.layers.core.lambda_layer.Lambda object at 0x79f46c69ddb0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x79f46c428280>, because it is not built.
# W0815 18:36:13.012198 134095775469568 save_impl.py:66] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x79f46c428280>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.src.layers.core.lambda_layer.Lambda object at 0x79f46c42b3a0>, because it is not built.
# W0815 18:36:13.012262 134095775469568 save_impl.py:66] Skipping full serialization of Keras layer <keras.src.layers.core.lambda_layer.Lambda object at 0x79f46c42b3a0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x79f46c42a5f0>, because it is not built.
# W0815 18:36:13.012318 134095775469568 save_impl.py:66] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x79f46c42a5f0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.src.layers.core.lambda_layer.Lambda object at 0x79f46c428640>, because it is not built.
# W0815 18:36:13.012379 134095775469568 save_impl.py:66] Skipping full serialization of Keras layer <keras.src.layers.core.lambda_layer.Lambda object at 0x79f46c428640>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x79f46c60c070>, because it is not built.
# W0815 18:36:13.012435 134095775469568 save_impl.py:66] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x79f46c60c070>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.src.layers.core.lambda_layer.Lambda object at 0x79f46c60c8e0>, because it is not built.
# W0815 18:36:13.012492 134095775469568 save_impl.py:66] Skipping full serialization of Keras layer <keras.src.layers.core.lambda_layer.Lambda object at 0x79f46c60c8e0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x79f46c60e950>, because it is not built.
# W0815 18:36:13.012547 134095775469568 save_impl.py:66] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x79f46c60e950>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.src.layers.core.lambda_layer.Lambda object at 0x79f46c60c610>, because it is not built.
# W0815 18:36:13.012602 134095775469568 save_impl.py:66] Skipping full serialization of Keras layer <keras.src.layers.core.lambda_layer.Lambda object at 0x79f46c60c610>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x79f46c60c7f0>, because it is not built.
# W0815 18:36:13.012659 134095775469568 save_impl.py:66] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x79f46c60c7f0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.src.layers.core.lambda_layer.Lambda object at 0x79f46c60ec20>, because it is not built.
# W0815 18:36:13.012714 134095775469568 save_impl.py:66] Skipping full serialization of Keras layer <keras.src.layers.core.lambda_layer.Lambda object at 0x79f46c60ec20>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x79f46c1e8b50>, because it is not built.
# W0815 18:36:13.012769 134095775469568 save_impl.py:66] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x79f46c1e8b50>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.src.layers.core.lambda_layer.Lambda object at 0x79f46c1e9b40>, because it is not built.
# W0815 18:36:13.101251 134095775469568 save_impl.py:66] Skipping full serialization of Keras layer <keras.src.layers.core.lambda_layer.Lambda object at 0x79f46c1e9b40>, because it is not built.
# I0815 18:36:26.905958 134095775469568 save.py:274] Found untraced functions such as WeightSharedConvolutionalBoxPredictor_layer_call_fn, WeightSharedConvolutionalBoxPredictor_layer_call_and_return_conditional_losses, WeightSharedConvolutionalBoxHead_layer_call_fn, WeightSharedConvolutionalBoxHead_layer_call_and_return_conditional_losses, WeightSharedConvolutionalClassHead_layer_call_fn while saving (showing 5 of 173). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: /content/exported_model/saved_model/assets
# I0815 18:36:33.393403 134095775469568 builder_impl.py:804] Assets written to: /content/exported_model/saved_model/assets
# I0815 18:36:33.724088 134095775469568 fingerprinting_utils.py:48] Writing fingerprint to /content/exported_model/saved_model/fingerprint.pb
# INFO:tensorflow:Writing pipeline config file to /content/exported_model/pipeline.config
# I0815 18:36:34.358988 134095775469568 config_util.py:253] Writing pipeline config file to /content/exported_model/pipeline.config

# %%
# !zip -r /content/exported_model.zip /content/exported_model
# Out:
#   adding: content/exported_model/ (stored 0%)
#   adding: content/exported_model/checkpoint/ (stored 0%)
#   adding: content/exported_model/checkpoint/checkpoint (deflated 41%)
#   adding: content/exported_model/checkpoint/ckpt-0.data-00000-of-00001 (deflated 8%)
#   adding: content/exported_model/checkpoint/ckpt-0.index (deflated 80%)
#   adding: content/exported_model/saved_model/ (stored 0%)
#   adding: content/exported_model/saved_model/saved_model.pb (deflated 92%)
#   adding: content/exported_model/saved_model/assets/ (stored 0%)
#   adding: content/exported_model/saved_model/variables/ (stored 0%)
#   adding: content/exported_model/saved_model/variables/variables.data-00000-of-00001 (deflated 9%)
#   adding: content/exported_model/saved_model/variables/variables.index (deflated 78%)
#   adding: content/exported_model/saved_model/fingerprint.pb (stored 0%)
#   adding: content/exported_model/pipeline.config (deflated 69%)

# %%
from psutil import virtual_memory
ram_gb = virtual_memory().total / 1e9
print('Your runtime has {:.1f} gigabytes of available RAM\n'.format(ram_gb))

if ram_gb < 20:
  print('Not using a high-RAM runtime')
else:
  print('You are using a high-RAM runtime!')
# Out:
# Your runtime has 37.8 gigabytes of available RAM
#
# You are using a high-RAM runtime!
